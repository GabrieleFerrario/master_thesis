# %%
import pandas as pd
import json
import plotly.express as px
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from imantics import Polygons, Mask, BBox
from pycocotools import mask as maskUtils

from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

lemmatizer = WordNetLemmatizer()

import warnings
warnings.filterwarnings("ignore")

from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# # COCO

# %%
f = open('coco/instances_val2017.json')
data = json.load(f)

f = open('coco/panoptic_val2017.json')
data_panoptic = json.load(f)

f = open('coco/stuff_val2017.json')
data_stuff = json.load(f)

# %%
new_data_panoptic = list()
for elem in data_panoptic["annotations"]:
    for seg in elem["segments_info"]:
        segment = seg
        segment["file_name"]=elem["file_name"]
        segment["image_id"]=elem["image_id"]
        segment["x1"]=segment["bbox"][0]
        segment["x2"]=segment["bbox"][1]
        segment["x3"]=segment["bbox"][2]
        segment["x4"]=segment["bbox"][3]
        new_data_panoptic.append(segment)

# %%
len(new_data_panoptic)
# Out:
# 56728

# %%
df_panoptic = pd.DataFrame(new_data_panoptic)
df_panoptic
# Out:
#             id  category_id  iscrowd                  bbox   area  \
# 0      3226956            1        0   [413, 158, 53, 138]   2840
# 1      6979964            1        0    [384, 172, 16, 36]    439
# 2      3103374           62        0    [413, 223, 30, 81]   1250
# 3      2831194           62        0    [291, 218, 62, 98]   1848
# 4      3496593           62        0    [412, 219, 10, 13]     90
# ...        ...          ...      ...                   ...    ...
# 56723  8703197           52        0  [467, 280, 173, 177]  22042
# 56724  1938563           52        0  [137, 216, 297, 100]  13576
# 56725  1995653           52        1     [0, 20, 640, 458]  24925
# 56726  1325130          122        0      [0, 0, 640, 478]  83419
# 56727  1252129          195        0      [0, 0, 578, 478]  52789
#
#               file_name  image_id   x1   x2   x3   x4
# 0      000000000139.png       139  413  158   53  138
# 1      000000000139.png       139  384  172   16   36
# 2      000000000139.png       139  413  223   30   81
# 3      000000000139.png       139  291  218   62   98
# 4      000000000139.png       139  412  219   10   13
# ...                 ...       ...  ...  ...  ...  ...
# 56723  000000581781.png    581781  467  280  173  177
# 56724  000000581781.png    581781  137  216  297  100
# 56725  000000581781.png    581781    0   20  640  458
# 56726  000000581781.png    581781    0    0  640  478
# 56727  000000581781.png    581781    0    0  578  478
#
# [56728 rows x 11 columns]

# %%
new_data_stuff = list()
for elem in data_stuff["annotations"]:
    segment = elem
    segment["x1"]=segment["bbox"][0]
    segment["x2"]=segment["bbox"][1]
    segment["x3"]=segment["bbox"][2]
    segment["x4"]=segment["bbox"][3]
    new_data_stuff.append(segment)

# %%
df_stuff = pd.DataFrame(new_data_stuff).rename(columns={"category_id": "category_id_stuff", "id": "id_stuff", "bbox": "bbox_stuff"})
df_stuff = df_stuff[df_stuff["category_id_stuff"]!=183] # rimuovo classe other
df_stuff
# Out:
#                                             segmentation      area  iscrowd  \
# 0      {'counts': 'j19[6h1ZNXNf1h1ZNYNe1g1[NYNf1f1YNZ...   25483.0        0
# 1      {'counts': '`bh11Y=1O1O1O1O001O001O001O001O001...   20106.0        0
# 2      {'counts': 'omh51Y=0ng31PXL01O10iW10ThN1PPY2',...      11.0        0
# 3      {'counts': '_:k2_:00000O1000000000000O10000000...   49754.0        0
# 4      {'counts': 'Qi\4:k<6O1bCAo;`0kC@M1W<n0O0N12O1O...     842.0        0
# ...                                                  ...       ...      ...
# 32794  {'counts': '0Y1l>l3O10OO2M300N101O1N101O1N101N...  176577.0        0
# 32796  {'counts': '0[6c0\Lf4e3ZKZLf4b1mJfM>g0e4U1^KQN...   83419.0        0
# 32797  {'counts': '[6c0\>0O1O100O2N1O101N2N1O2N1O010O...    1167.0        0
# 32798  {'counts': 'e9T4j:O1YL[ET3Y;N1O10001O000000010...   52789.0        0
# 32799  {'counts': 'cVX64j>2N0[AL_>5_AO_>702O0O2aB@^<`...    1473.0        0
#
#        image_id                  bbox_stuff  category_id_stuff  id_stuff  \
# 0           139   [0.0, 38.0, 549.0, 297.0]                 98  20000000
# 1           139  [136.0, 0.0, 473.0, 116.0]                102  20000001
# 2           139  [444.0, 226.0, 20.0, 11.0]                105  20000002
# 3           139  [0.0, 269.0, 564.0, 157.0]                118  20000003
# 4           139  [338.0, 166.0, 29.0, 50.0]                119  20000004
# ...         ...                         ...                ...       ...
# 32794    581615    [0.0, 0.0, 478.0, 640.0]                176  20032794
# 32796    581781    [0.0, 0.0, 640.0, 478.0]                122  20032796
# 32797    581781    [0.0, 203.0, 40.0, 40.0]                123  20032797
# 32798    581781    [0.0, 0.0, 578.0, 478.0]                139  20032798
# 32799    581781  [428.0, 407.0, 51.0, 71.0]                143  20032799
#
#           x1     x2     x3     x4
# 0        0.0   38.0  549.0  297.0
# 1      136.0    0.0  473.0  116.0
# 2      444.0  226.0   20.0   11.0
# 3        0.0  269.0  564.0  157.0
# 4      338.0  166.0   29.0   50.0
# ...      ...    ...    ...    ...
# 32794    0.0    0.0  478.0  640.0
# 32796    0.0    0.0  640.0  478.0
# 32797    0.0  203.0   40.0   40.0
# 32798    0.0    0.0  578.0  478.0
# 32799  428.0  407.0   51.0   71.0
#
# [27849 rows x 11 columns]

# %%
df_things = pd.DataFrame(data["annotations"])
df_things["file_name"]=df_things['image_id'].apply(lambda x: '{0:0>16}'.format(str(x)+".jpg"))
df_things[['x1','x2', 'x3', 'x4']] = pd.DataFrame(df_things.bbox.tolist(), index= df_things.index)
df_things = df_things.sort_values(by=['image_id',"area"])

df_things
# Out:
#                                             segmentation         area  \
# 27924  [[413.7, 220.47, 412.25, 231.06, 419.96, 231.5...     90.98725
# 28442  [[339.52, 201.72, 336.79, 216.23, 346.35, 214....    120.23200
# 27503  [[361.37, 229.69, 361.56, 226.09, 360.42, 220....    178.18510
# 28441  [[242.95, 212.06, 241.24, 199.54, 254.32, 194....    189.56010
# 24602  [[317.4, 219.24, 319.8, 230.83, 338.98, 230.03...    210.14820
# ...                                                  ...          ...
# 19107  [[140.71, 217.49, 147.16, 216.41, 201.94, 236....  13574.45810
# 19164  [[40.91, 197.01, 37.68, 228.23, 3.23, 305.75, ...  14836.26035
# 19176  [[587.56, 253.32, 556.41, 260.84, 540.3, 266.2...  16690.94945
# 19151  [[532.91, 296.6, 570.59, 305.21, 589.96, 304.1...  22016.99120
# 36740  {'counts': [468, 6, 444, 6, 13, 4, 1, 12, 1, 1...  28911.00000
#
#        iscrowd  image_id                              bbox  category_id  \
# 27924        0       139     [412.25, 219.02, 9.63, 12.52]           62
# 28442        0       139      [336.79, 199.5, 9.73, 16.73]           86
# 27503        0       139    [350.76, 208.84, 11.37, 22.55]           86
# 28441        0       139    [241.24, 194.99, 14.22, 17.63]           86
# 24602        0       139     [317.4, 219.24, 21.58, 11.59]           62
# ...        ...       ...                               ...          ...
# 19107        0    581781    [136.42, 216.41, 297.54, 99.9]           52
# 19164        0    581781     [2.15, 184.09, 137.8, 159.34]           52
# 19176        0    581781   [439.33, 94.35, 160.05, 171.86]           52
# 19151        0    581781  [467.23, 280.45, 172.77, 177.63]           52
# 36740        1    581781                 [0, 20, 639, 457]           52
#
#                  id         file_name      x1      x2      x3      x4
# 27924       1941808  000000000139.jpg  412.25  219.02    9.63   12.52
# 28442       2146548  000000000139.jpg  336.79  199.50    9.73   16.73
# 27503       1669970  000000000139.jpg  350.76  208.84   11.37   22.55
# 28441       2146194  000000000139.jpg  241.24  194.99   14.22   17.63
# 24602        110334  000000000139.jpg  317.40  219.24   21.58   11.59
# ...             ...               ...     ...     ...     ...     ...
# 19107       1544126  000000581781.jpg  136.42  216.41  297.54   99.90
# 19164       1547489  000000581781.jpg    2.15  184.09  137.80  159.34
# 19176       1547752  000000581781.jpg  439.33   94.35  160.05  171.86
# 19151       1546551  000000581781.jpg  467.23  280.45  172.77  177.63
# 36740  905200581781  000000581781.jpg    0.00   20.00  639.00  457.00
#
# [36781 rows x 12 columns]

# %%
# final df 
df_coco = pd.merge(df_panoptic, df_stuff, on=['image_id', "x1", "x2", "x3", "x4"])[["id","category_id", "bbox","area_x", "file_name", "image_id", "segmentation", "id_stuff", "category_id_stuff","x1", "x2", "x3", "x4"]].rename(columns={"area_x": "area"})
df_coco["file_name"] = df_coco["file_name"].str.replace(".png",".jpg")
df_coco = pd.concat([df_coco, df_things]).sort_values(by=['image_id',"category_id"])
df_coco = df_coco.drop_duplicates(subset=["category_id", "image_id", "x1", "x2", "x3", "x4"])[["id", "category_id", "bbox", "area", "file_name", "image_id", "segmentation"]]

df_coco
# Out:
#                  id  category_id                              bbox  \
# 24776        233201            1    [384.43, 172.21, 15.12, 35.74]
# 24772        230831            1    [412.8, 157.61, 53.05, 138.01]
# 27924       1941808           62     [412.25, 219.02, 9.63, 12.52]
# 24602        110334           62     [317.4, 219.24, 21.58, 11.59]
# 24577        105328           62     [413.2, 223.01, 30.17, 81.36]
# ...             ...          ...                               ...
# 19176       1547752           52   [439.33, 94.35, 160.05, 171.86]
# 19151       1546551           52  [467.23, 280.45, 172.77, 177.63]
# 36740  905200581781           52                 [0, 20, 639, 457]
# 19097       1325130          122                  [0, 0, 640, 478]
# 19098       1252129          195                  [0, 0, 578, 478]
#
#               area         file_name  image_id  \
# 24776    435.14495  000000000139.jpg       139
# 24772   2913.11040  000000000139.jpg       139
# 27924     90.98725  000000000139.jpg       139
# 24602    210.14820  000000000139.jpg       139
# 24577   1289.37345  000000000139.jpg       139
# ...            ...               ...       ...
# 19176  16690.94945  000000581781.jpg    581781
# 19151  22016.99120  000000581781.jpg    581781
# 36740  28911.00000  000000581781.jpg    581781
# 19097  83419.00000  000000581781.jpg    581781
# 19098  52789.00000  000000581781.jpg    581781
#
#                                             segmentation
# 24776  [[384.98, 206.58, 384.43, 199.98, 385.25, 193....
# 24772  [[428.19, 219.47, 430.94, 209.57, 430.39, 210....
# 27924  [[413.7, 220.47, 412.25, 231.06, 419.96, 231.5...
# 24602  [[317.4, 219.24, 319.8, 230.83, 338.98, 230.03...
# 24577  [[436.06, 304.37, 443.37, 300.71, 436.97, 261....
# ...                                                  ...
# 19176  [[587.56, 253.32, 556.41, 260.84, 540.3, 266.2...
# 19151  [[532.91, 296.6, 570.59, 305.21, 589.96, 304.1...
# 36740  {'counts': [468, 6, 444, 6, 13, 4, 1, 12, 1, 1...
# 19097  {'counts': '0[6c0\Lf4e3ZKZLf4b1mJfM>g0e4U1^KQN...
# 19098  {'counts': 'e9T4j:O1YL[ET3Y;N1O10001O000000010...
#
# [55849 rows x 7 columns]

# %%
f = open('../coco/coco_categories_final.json')
 
df_coco_categories_final = pd.DataFrame(json.load(f))
df_coco_categories_final
# Out:
#     supercategory   id           name   count  isthing  \
# 0          person    1         person  262351      NaN
# 1            wall  199           wall   43524      0.0
# 2         vehicle    3            car   43510      NaN
# 3           plant  184           tree   41075      0.0
# 4             sky  187            sky   40119      0.0
# ..            ...  ...            ...     ...      ...
# 128    structural  138            net    1362      0.0
# 129       outdoor   14  parking meter    1285      NaN
# 130        animal   23           bear    1282      NaN
# 131     appliance   80        toaster     224      NaN
# 132        indoor   89     hair dryer     198      NaN
#
#                                         original_class dataset
# 0    {'original_class': 'person', 'original_id': 1,...    COCO
# 1    {'original_class': 'wall-other-merged', 'origi...    COCO
# 2    {'original_class': 'car', 'original_id': 3, 'd...    COCO
# 3    {'original_class': 'tree-merged', 'original_id...    COCO
# 4    {'original_class': 'sky-other-merged', 'origin...    COCO
# ..                                                 ...     ...
# 128  {'original_class': 'net', 'original_id': 138, ...    COCO
# 129  {'original_class': 'parking meter', 'original_...    COCO
# 130  {'original_class': 'bear', 'original_id': 23, ...    COCO
# 131  {'original_class': 'toaster', 'original_id': 8...    COCO
# 132  {'original_class': 'hair drier', 'original_id'...    COCO
#
# [133 rows x 7 columns]

# %%
df_coco = pd.merge(df_coco_categories_final.rename(columns={"id": "category_id"}), df_coco, on="category_id")
df_coco
# Out:
#       supercategory  category_id        name   count  isthing  \
# 0            person            1      person  262351      NaN
# 1            person            1      person  262351      NaN
# 2            person            1      person  262351      NaN
# 3            person            1      person  262351      NaN
# 4            person            1      person  262351      NaN
# ...             ...          ...         ...     ...      ...
# 55844        indoor           89  hair dryer     198      NaN
# 55845        indoor           89  hair dryer     198      NaN
# 55846        indoor           89  hair dryer     198      NaN
# 55847        indoor           89  hair dryer     198      NaN
# 55848        indoor           89  hair dryer     198      NaN
#
#                                           original_class dataset       id  \
# 0      {'original_class': 'person', 'original_id': 1,...    COCO   233201
# 1      {'original_class': 'person', 'original_id': 1,...    COCO   230831
# 2      {'original_class': 'person', 'original_id': 1,...    COCO   442619
# 3      {'original_class': 'person', 'original_id': 1,...    COCO   559508
# 4      {'original_class': 'person', 'original_id': 1,...    COCO   560228
# ...                                                  ...     ...      ...
# 55844  {'original_class': 'hair drier', 'original_id'...    COCO  1676045
# 55845  {'original_class': 'hair drier', 'original_id'...    COCO  1188212
# 55846  {'original_class': 'hair drier', 'original_id'...    COCO  1675983
# 55847  {'original_class': 'hair drier', 'original_id'...    COCO  2197655
# 55848  {'original_class': 'hair drier', 'original_id'...    COCO  1188281
#
#                                    bbox         area         file_name  \
# 0        [384.43, 172.21, 15.12, 35.74]    435.14495  000000000139.jpg
# 1        [412.8, 157.61, 53.05, 138.01]   2913.11040  000000000139.jpg
# 2        [280.79, 44.73, 218.7, 346.68]  27789.11055  000000000785.jpg
# 3      [145.26, 100.67, 291.95, 457.35]  25759.04240  000000000872.jpg
# 4       [163.73, 126.42, 265.69, 480.4]  48091.75195  000000000872.jpg
# ...                                 ...          ...               ...
# 55844     [0.0, 101.67, 163.96, 181.22]  22528.82730  000000350002.jpg
# 55845   [315.51, 187.84, 83.23, 226.16]   5066.24570  000000384136.jpg
# 55846     [139.83, 48.57, 28.71, 38.29]    592.16200  000000500464.jpg
# 55847     [155.44, 24.76, 34.97, 20.73]    302.02640  000000501368.jpg
# 55848  [194.58, 209.63, 144.71, 229.02]  10347.80605  000000569976.jpg
#
#        image_id                                       segmentation
# 0           139  [[384.98, 206.58, 384.43, 199.98, 385.25, 193....
# 1           139  [[428.19, 219.47, 430.94, 209.57, 430.39, 210....
# 2           785  [[353.37, 67.65, 358.15, 52.37, 362.92, 47.59,...
# 3           872  [[310.65, 112.18, 339.42, 100.67, 362.43, 106....
# 4           872  [[233.87, 606.82, 187.55, 602.85, 220.64, 580....
# ...         ...                                                ...
# 55844    350002  [[48.9, 274.26, 119.37, 282.89, 163.96, 242.62...
# 55845    384136  [[386.71, 211.78, 375.66, 192.14, 352.95, 187....
# 55846    500464  [[168.54, 86.47, 168.35, 86.86, 161.71, 85.69,...
# 55847    501368  [[155.44, 37.72, 177.46, 24.76, 190.41, 26.06,...
# 55848    569976  [[270.38, 336.54, 281.89, 320.72, 304.9, 340.8...
#
# [55849 rows x 13 columns]

# %%
len(set(df_coco["category_id"]))
# Out:
# 133

# %%
df_coco["name"].value_counts()
# Out:
# person        11006
# wall           2363
# car            1932
# chair          1791
# sky            1611
#               ...
# microwave        55
# net              53
# scissors         36
# hair dryer       11
# toaster           9
# Name: name, Length: 127, dtype: int64

# %% [markdown]
# # LVIS

# %%
f = open('lvis/lvis_v1_val.json')
data_lvis = json.load(f)
df_lvis_annotations = pd.DataFrame(data_lvis["annotations"])
df_lvis_annotations
# Out:
#              area      id                                       segmentation  \
# 0        73297.48       1  [[270.75, 598.57, 261.98, 598.57, 247.84, 598....
# 1        70204.06       2  [[0.0, 626.21, 90.53, 629.18, 97.12, 611.7, 10...
# 2          289.97       3  [[238.16, 386.84, 240.61, 387.95, 245.96, 385....
# 3          238.39       4  [[392.16, 220.43, 395.79, 219.28, 400.38, 216....
# 4       100734.18       5  [[23.83, 156.28, 0.0, 162.64, 0.0, 427.0, 166....
# ...           ...     ...                                                ...
# 244702       4.72  244703  [[209.04, 181.65, 208.15, 182.21, 207.92, 182....
# 244703      15.41  244704  [[72.17, 253.4, 74.78, 254.09, 75.99, 252.7, 7...
# 244704       2.75  244705  [[24.1, 257.12, 24.62, 257.47, 25.15, 257.64, ...
# 244705       5.38  244706  [[215.52, 186.01, 214.45, 185.69, 213.38, 185....
# 244706       8.27  244707  [[209.38, 180.15, 208.42, 180.06, 208.33, 179....
#
#         image_id                             bbox  category_id
# 0         446522  [83.08, 219.88, 301.69, 420.12]          232
# 1         446522       [0.0, 0.0, 132.41, 629.18]          421
# 2          76261   [238.16, 340.87, 66.44, 47.08]           99
# 3          76261   [368.84, 181.21, 51.42, 59.88]           99
# 4         454750       [0.0, 14.7, 413.66, 412.3]         1202
# ...          ...                              ...          ...
# 244702    358717      [207.92, 181.65, 2.35, 2.8]          125
# 244703    358717        [71.65, 249.5, 4.6, 4.59]          125
# 244704    358717        [24.1, 256.0, 2.17, 1.64]          125
# 244705    358717     [212.74, 185.69, 2.86, 2.46]          125
# 244706    358717      [208.33, 177.29, 3.3, 2.95]          125
#
# [244707 rows x 6 columns]

# %%
len(set(df_lvis_annotations["image_id"]))
# Out:
# 19626

# %%
f = open('../lvis/lvis_categories_final.json')
df_lvis_categories_final = pd.DataFrame(json.load(f))
df_lvis_categories_final
# Out:
#        name  instance_count  \
# 0    banana           50552
# 1      book           33353
# 2    carrot           18049
# 3     apple           17451
# 4      pole           14276
# ..      ...             ...
# 586  animal             103
# 587    sled             102
# 588     van             102
# 589   fruit             101
# 590   clock             100
#
#                                                    def  \
# 0    elongated crescent-shaped yellow fruit with so...
# 1    a written work or composition that has been pu...
# 2    deep orange edible root of the cultivated carr...
# 3    fruit with red or yellow or green skin and swe...
# 4    a long (usually round) rod of wood or metal or...
# ..                                                 ...
# 586  a domesticated animal kept for companionship o...
# 587  a vehicle or flat object for transportation ov...
# 588  a recreational vehicle equipped for camping ou...
# 589    any of numerous inedible fruits with hard rinds
# 590                          a clock mounted on a wall
#
#                                         synonyms  image_count    id frequency  \
# 0                                       [banana]         1787    45         f
# 1                                         [book]         1903   127         f
# 2                                       [carrot]         1222   217         f
# 3                                        [apple]         1207    12         f
# 4                                   [pole, post]         1890   827         f
# ..                                           ...          ...   ...       ...
# 586                                        [pet]           79   794         c
# 587                       [sled, sledge, sleigh]           56   970         c
# 588  [camper_(vehicle), camping_bus, motor_home]           40   191         c
# 589                                      [gourd]            6   509         r
# 590                                 [wall_clock]           48  1154         c
#
#               synset                                     original_class  \
# 0        banana.n.02  {'original_class': 'banana', 'original_id': 45...
# 1          book.n.01  {'original_class': 'book', 'original_id': 127,...
# 2        carrot.n.01  {'original_class': 'carrot', 'original_id': 21...
# 3         apple.n.01  {'original_class': 'apple', 'original_id': 12,...
# 4          pole.n.01  {'original_class': 'pole', 'original_id': 827,...
# ..               ...                                                ...
# 586         pet.n.01  {'original_class': 'pet', 'original_id': 794, ...
# 587        sled.n.01  {'original_class': 'sled', 'original_id': 970,...
# 588      camper.n.02  {'original_class': 'camper_(vehicle)', 'origin...
# 589       gourd.n.02  {'original_class': 'gourd', 'original_id': 509...
# 590  wall_clock.n.01  {'original_class': 'wall_clock', 'original_id'...
#
#     dataset
# 0      LVIS
# 1      LVIS
# 2      LVIS
# 3      LVIS
# 4      LVIS
# ..      ...
# 586    LVIS
# 587    LVIS
# 588    LVIS
# 589    LVIS
# 590    LVIS
#
# [591 rows x 10 columns]

# %%
len(set(df_lvis_categories_final["name"].values))
# Out:
# 521

# %%
df_lvis = pd.merge(df_lvis_categories_final, df_lvis_annotations.rename(columns={"id": "id_annotations", "category_id": "id"}), on="id")
df_lvis
# Out:
#           name  instance_count  \
# 0       banana           50552
# 1       banana           50552
# 2       banana           50552
# 3       banana           50552
# 4       banana           50552
# ...        ...             ...
# 240882   clock             100
# 240883   clock             100
# 240884   clock             100
# 240885   clock             100
# 240886   clock             100
#
#                                                       def      synonyms  \
# 0       elongated crescent-shaped yellow fruit with so...      [banana]
# 1       elongated crescent-shaped yellow fruit with so...      [banana]
# 2       elongated crescent-shaped yellow fruit with so...      [banana]
# 3       elongated crescent-shaped yellow fruit with so...      [banana]
# 4       elongated crescent-shaped yellow fruit with so...      [banana]
# ...                                                   ...           ...
# 240882                          a clock mounted on a wall  [wall_clock]
# 240883                          a clock mounted on a wall  [wall_clock]
# 240884                          a clock mounted on a wall  [wall_clock]
# 240885                          a clock mounted on a wall  [wall_clock]
# 240886                          a clock mounted on a wall  [wall_clock]
#
#         image_count    id frequency           synset  \
# 0              1787    45         f      banana.n.02
# 1              1787    45         f      banana.n.02
# 2              1787    45         f      banana.n.02
# 3              1787    45         f      banana.n.02
# 4              1787    45         f      banana.n.02
# ...             ...   ...       ...              ...
# 240882           48  1154         c  wall_clock.n.01
# 240883           48  1154         c  wall_clock.n.01
# 240884           48  1154         c  wall_clock.n.01
# 240885           48  1154         c  wall_clock.n.01
# 240886           48  1154         c  wall_clock.n.01
#
#                                            original_class dataset     area  \
# 0       {'original_class': 'banana', 'original_id': 45...    LVIS   216.73
# 1       {'original_class': 'banana', 'original_id': 45...    LVIS   153.76
# 2       {'original_class': 'banana', 'original_id': 45...    LVIS   366.66
# 3       {'original_class': 'banana', 'original_id': 45...    LVIS   195.67
# 4       {'original_class': 'banana', 'original_id': 45...    LVIS    24.90
# ...                                                   ...     ...      ...
# 240882  {'original_class': 'wall_clock', 'original_id'...    LVIS  4933.66
# 240883  {'original_class': 'wall_clock', 'original_id'...    LVIS  1955.59
# 240884  {'original_class': 'wall_clock', 'original_id'...    LVIS  3344.10
# 240885  {'original_class': 'wall_clock', 'original_id'...    LVIS  3799.83
# 240886  {'original_class': 'wall_clock', 'original_id'...    LVIS   174.49
#
#         id_annotations                                       segmentation  \
# 0                  558  [[347.16, 146.34, 348.62, 148.35, 348.62, 150....
# 1                  559  [[454.44, 130.81, 458.22, 129.49, 461.43, 128....
# 2                  560  [[357.26, 131.01, 355.56, 133.39, 356.58, 134....
# 3                  561  [[437.8, 134.13, 441.01, 130.57, 444.93, 128.9...
# 4                  562  [[308.01, 174.28, 307.26, 175.4, 306.7, 176.16...
# ...                ...                                                ...
# 240882          120495  [[201.58, 0.0, 201.16, 18.15, 199.46, 21.55, 2...
# 240883          126976  [[496.41, 110.32, 500.47, 105.59, 503.04, 100....
# 240884          130543  [[166.72, 44.26, 175.38, 43.07, 182.68, 41.71,...
# 240885          130544  [[482.2, 122.5, 443.61, 121.3, 440.4, 116.75, ...
# 240886          172071  [[306.18, 236.17, 308.64, 236.31, 311.24, 237....
#
#         image_id                            bbox
# 0         480275  [344.41, 134.46, 21.78, 17.91]
# 1         480275  [449.72, 128.35, 18.13, 14.72]
# 2         480275  [355.56, 130.84, 41.34, 16.32]
# 3         480275  [435.31, 127.72, 18.53, 20.48]
# 4         480275   [297.86, 171.27, 10.15, 4.89]
# ...          ...                             ...
# 240882    497558     [186.71, 0.0, 67.98, 112.9]
# 240883    384793    [462.01, 60.78, 44.0, 57.62]
# 240884     65329      [97.35, 0.0, 85.33, 44.94]
# 240885     65329    [433.86, 46.37, 60.5, 76.13]
# 240886    499147   [306.18, 236.17, 10.26, 23.8]
#
# [240887 rows x 15 columns]

# %%
len(set(df_lvis["name"]))
# Out:
# 521

# %% [markdown]
# Sistemo COCO per eliminare le annotazioni duplicate

# %%
unique_lvis_classes = list(set(df_lvis["name"].values) - set(df_coco["name"].values))
print("numero di classi presenti solo in LVIS:",len(unique_lvis_classes))
unique_lvis_classes
# Out:
# numero di classi presenti solo in LVIS: 437
# ['juice',
#  'tassel',
#  'scale',
#  'propeller',
#  'jean',
#  'egg',
#  'cupboard',
#  'pouch',
#  'wine bottle',
#  'telephone',
#  'peach',
#  'corn',
#  'short',
#  'chandelier',
#  'birthday cake',
#  'hat',
#  'sandal',
#  'statue',
#  'thumbtack',
#  'street sign',
#  'clay',
#  'trunk',
#  'cornice',
#  'billboard',
#  'clip',
#  'napkin',
#  'water bottle',
#  'ladle',
#  'visor',
#  'chili (vegetable)',
#  'deer',
#  'pear',
#  'pipe',
#  'raincoat',
#  'earphone',
#  'weather vane',
#  'light bulb',
#  'lamp',
#  'sock',
#  'blinder (for horses)',
#  'microphone',
#  'saucer',
#  'crouton',
#  'handle',
#  'box',
#  'tongs',
#  'cart',
#  'legging',
#  'skirt',
#  'headboard',
#  'duck',
#  'goggles',
#  'mattress',
#  'bar',
#  'newspaper',
#  'laptop computer',
#  'folding chair',
#  'underwear',
#  'tortilla',
#  'scoreboard',
#  'faucet',
#  'paper plate',
#  'pineapple',
#  'cherry',
#  'animal',
#  'teapot',
#  'hamburger',
#  'wallet',
#  'bull',
#  'polar bear',
#  'shopping bag',
#  'cone',
#  'gift',
#  'toaster oven',
#  'monkey',
#  'belt buckle',
#  'coin',
#  'street light',
#  'tomato',
#  'nut',
#  'suit',
#  'sunflower',
#  'blender',
#  'tank top',
#  'chip',
#  'lettuce',
#  'cracker',
#  'sculpture',
#  'baseball cap',
#  'stove',
#  'wheel',
#  'printer',
#  'soap',
#  'bird cage',
#  'bell',
#  'home plate',
#  'sunglasses',
#  'saddle',
#  'plate',
#  'trash can',
#  'flower pot',
#  'watermelon',
#  'trousers',
#  'shirt',
#  'brush',
#  'costume',
#  'bow tie',
#  'notebook',
#  'glasses',
#  'collar',
#  'clasp',
#  'radish',
#  'pumpkin',
#  'coat',
#  'magazine',
#  'knee pad',
#  'coconut',
#  'can',
#  'beach chair',
#  'cigarette',
#  'strawberry',
#  'hook',
#  'mug',
#  'lock',
#  'bread',
#  'toilet paper',
#  'beanie',
#  'glove',
#  'radio',
#  'cucumber',
#  'control',
#  'bobbin',
#  'flamingo',
#  'soccer ball',
#  'coaster',
#  'milk',
#  'avocado',
#  'pad',
#  'jar',
#  'wet suit',
#  'wheelchair',
#  'strap',
#  'butter',
#  'canister',
#  'bath towel',
#  'dishwasher',
#  'butterfly',
#  'mushroom',
#  'log',
#  'balloon',
#  'hanger',
#  'goose',
#  'window box (for plants)',
#  'battery',
#  'jacket',
#  'condiment',
#  'toothpick',
#  'mat',
#  'socket',
#  'scarf',
#  'oar',
#  'pastry',
#  'lanyard',
#  'necklace',
#  'urinal',
#  'tape',
#  'camera',
#  'potato',
#  'binder',
#  'belt',
#  'soda can',
#  'shrimp',
#  'boot',
#  'carton',
#  'chocolate',
#  'shoe',
#  'pickup truck',
#  'bottle cap',
#  'broom',
#  'cooler',
#  'date (fruit)',
#  'ring',
#  'panda',
#  'rabbit',
#  'ham',
#  'celery',
#  'tag',
#  'poster',
#  'jersey',
#  'croissant',
#  'vest',
#  'crate',
#  'coffee maker',
#  'pot',
#  'pencil',
#  'muffin',
#  'hinge',
#  'doorknob',
#  'sausage',
#  'christmas tree',
#  'salad',
#  'tarp',
#  'candy',
#  'tank',
#  'fan',
#  'melon',
#  'alarm clock',
#  'coffee table',
#  'license plate',
#  'doll',
#  'heart',
#  'cutting board',
#  'necktie',
#  'grill',
#  'award',
#  'parasail',
#  'tablecloth',
#  'disc',
#  'lampshade',
#  'quilt',
#  'spatula',
#  'ladder',
#  'chopstick',
#  'chickpea',
#  'cowboy hat',
#  'figurine',
#  'lime',
#  'baseball',
#  'toy',
#  'sail',
#  'street lamp',
#  'ice cream',
#  'water tank',
#  'van',
#  'pen',
#  'school bus',
#  'lemon',
#  'saddle blanket',
#  'card',
#  'watch',
#  'painting',
#  'seashell',
#  'brownie',
#  'pepper',
#  'bathtub',
#  'crumb',
#  'shampoo',
#  'hood',
#  'pitcher',
#  'platter',
#  'pajama',
#  'onion',
#  'mitten',
#  'blueberry',
#  'sweatband',
#  'pin (non jewelry)',
#  'videotape',
#  'pan',
#  'stroller',
#  'speaker',
#  'blouse',
#  'fire truck',
#  'crown',
#  'bun',
#  'stool',
#  'map',
#  'bag',
#  'guitar',
#  'calendar',
#  'apron',
#  'stirrup',
#  'pole',
#  'money',
#  'dresser',
#  'bucket',
#  'kiwi',
#  'medicine cabinet',
#  'rubber band',
#  'blazer',
#  'beer bottle',
#  'shower curtain',
#  'headlight',
#  'buoy',
#  'paddle',
#  'drawer',
#  'blinker',
#  'hose',
#  'sign',
#  'lantern',
#  'straw',
#  'cube',
#  'asparagus',
#  'ottoman',
#  'computer mouse',
#  'salt shaker',
#  'mast',
#  'holder',
#  'basket',
#  'motor',
#  'hand towel',
#  'calf',
#  'band',
#  'bamboo',
#  'pie',
#  'stone',
#  'computer keyboard',
#  'sled',
#  'helmet',
#  'bedspread',
#  'kettle',
#  'smartphone',
#  'goat',
#  'stick',
#  'cupcake',
#  'dispenser',
#  'passenger train',
#  'mound',
#  'barrette',
#  'tray',
#  'foil',
#  'headstall (for horses)',
#  'toast',
#  'soup',
#  'ski pole',
#  'windmill',
#  'wagon',
#  'clock tower',
#  'cushion',
#  'sweater',
#  'spray bottle',
#  'artichoke',
#  'mixer',
#  'ipod',
#  'thermostat',
#  'steering wheel',
#  'fish',
#  'packet',
#  'flap',
#  'vegetable',
#  'paper towel',
#  'yogurt',
#  'sponge',
#  'whipped cream',
#  'bookcase',
#  'ski boot',
#  'candle',
#  'envelope',
#  'tripod',
#  'chicken',
#  'dress',
#  'cover',
#  'scooter',
#  'life preserver',
#  'magnet',
#  'swimsuit',
#  'blackberry',
#  'notepad',
#  'piano',
#  'mousepad',
#  'bead',
#  'pancake',
#  'cork (bottle plug)',
#  'chalkboard',
#  'raspberry',
#  'toothpaste',
#  'polo shirt',
#  'manhole',
#  'computer monitor',
#  'alcohol',
#  'knob',
#  'barrel',
#  'fireplace',
#  'fire extinguisher',
#  'cauliflower',
#  'marker',
#  'button',
#  'brake light',
#  'dish',
#  'flag',
#  'camera lens',
#  'mask',
#  'pennant',
#  'penguin',
#  'awning',
#  'bagel',
#  'kayak',
#  'cookie',
#  'bracelet',
#  'tennis ball',
#  'armchair',
#  'bandana',
#  'pigeon',
#  'pinecone',
#  'earring',
#  'air conditioner',
#  'mailbox',
#  'headband',
#  'sweet potato',
#  'brassiere',
#  'placemat',
#  'wire',
#  'fire alarm',
#  'grape',
#  'latch',
#  'antenna',
#  'shower head',
#  'sofa',
#  'minivan',
#  'meatball',
#  'wristband',
#  'clothespin',
#  'ski jacket',
#  'vent',
#  'remote control',
#  'taxi',
#  'bolt',
#  'bean',
#  'pickle',
#  'towel rack',
#  'sweatshirt',
#  'life jacket',
#  'desk',
#  'ashtray',
#  'reflector',
#  'almond',
#  'jet',
#  'telephone pole',
#  'key',
#  'zucchini',
#  'radiator',
#  'steak',
#  'candle holder',
#  'wreath',
#  'eggplant',
#  'trough',
#  'shovel',
#  'garlic']

# %%
unique_coco_classes = list(set(df_coco["name"].values) - set(df_lvis["name"].values))
print("numero di classi presenti solo in COCO:",len(unique_coco_classes))
unique_coco_classes
# Out:
# numero di classi presenti solo in COCO: 43
# ['laptop',
#  'keyboard',
#  'rug',
#  'plant',
#  'cell phone',
#  'roof',
#  'rock',
#  'mountain',
#  'hot dog',
#  'snow',
#  'sea',
#  'window',
#  'road',
#  'tie',
#  'remote',
#  'railroad',
#  'tent',
#  'sand',
#  'gravel',
#  'house',
#  'grass',
#  'light',
#  'furniture',
#  'dirt',
#  'staircase',
#  'fence',
#  'bridge',
#  'wall',
#  'tree',
#  'water',
#  'shelf',
#  'mouse',
#  'river',
#  'cardboard',
#  'pavement',
#  'sky',
#  'net',
#  'couch',
#  'door',
#  'building',
#  'platform',
#  'ceiling',
#  'floor']

# %%
df_lvis_images = pd.DataFrame(data_lvis["images"]).rename(columns={"id":"image_id"})
df_lvis_images
# Out:
#              date_captured                                   neg_category_ids  \
# 0      2013-11-14 17:02:52               [279, 899, 127, 180, 1136, 725, 663]
# 1      2013-11-14 20:55:31  [1002, 434, 924, 928, 951, 378, 1012, 867, 108...
# 2      2013-11-14 22:32:02  [194, 899, 248, 587, 201, 838, 1112, 1061, 337...
# 3      2013-11-14 23:11:37                    [149, 713, 654, 1112, 753, 579]
# 4      2013-11-14 23:16:55              [22, 369, 176, 653, 89, 11, 753, 474]
# ...                    ...                                                ...
# 19804  2013-11-24 13:20:54                [1014, 1148, 857, 80, 660, 142, 13]
# 19805  2013-11-24 20:54:28    [782, 1126, 608, 857, 1053, 486, 380, 992, 270]
# 19806  2013-11-24 21:59:45      [21, 857, 1008, 57, 800, 531, 15, 1202, 1120]
# 19807  2013-11-24 22:39:24                         [335, 1085, 672, 190, 489]
# 19808  2013-11-25 08:47:32  [452, 1166, 455, 738, 1151, 315, 1013, 1137, 3...
#
#        image_id  license  height  width  \
# 0        397133        4     427    640
# 1         37777        1     230    352
# 2        252219        4     428    640
# 3         87038        1     480    640
# 4        174482        6     388    640
# ...         ...      ...     ...    ...
# 19804    125910        4     640    480
# 19805    342307        3     375    500
# 19806    432062        1     433    640
# 19807    347405        3     427    640
# 19808    155379        6     480    640
#
#                                               flickr_url  \
# 0      http://farm7.staticflickr.com/6116/6255196340_...
# 1      http://farm9.staticflickr.com/8429/7839199426_...
# 2      http://farm4.staticflickr.com/3446/3232237447_...
# 3      http://farm8.staticflickr.com/7355/8825114508_...
# 4      http://farm8.staticflickr.com/7020/6478877255_...
# ...                                                  ...
# 19804  http://farm8.staticflickr.com/7392/9308795953_...
# 19805  http://farm4.staticflickr.com/3076/3160532038_...
# 19806  http://farm4.staticflickr.com/3114/2305083105_...
# 19807  http://farm6.staticflickr.com/5511/9585778258_...
# 19808  http://farm4.staticflickr.com/3760/9203741571_...
#
#                                                 coco_url  \
# 0      http://images.cocodataset.org/val2017/00000039...
# 1      http://images.cocodataset.org/val2017/00000003...
# 2      http://images.cocodataset.org/val2017/00000025...
# 3      http://images.cocodataset.org/val2017/00000008...
# 4      http://images.cocodataset.org/val2017/00000017...
# ...                                                  ...
# 19804  http://images.cocodataset.org/train2017/000000...
# 19805  http://images.cocodataset.org/train2017/000000...
# 19806  http://images.cocodataset.org/train2017/000000...
# 19807  http://images.cocodataset.org/train2017/000000...
# 19808  http://images.cocodataset.org/train2017/000000...
#
#       not_exhaustive_category_ids
# 0      [914, 801, 566, 139, 1021]
# 1                       [181, 45]
# 2                           [948]
# 3                      [94, 1043]
# 4                          [1112]
# ...                           ...
# 19804                      [1122]
# 19805                          []
# 19806                          []
# 19807                          []
# 19808                       [904]
#
# [19809 rows x 9 columns]

# %%
df_lvis = pd.merge(df_lvis, df_lvis_images, on="image_id")
df_lvis
# Out:
#           name  instance_count  \
# 0       banana           50552
# 1       banana           50552
# 2       banana           50552
# 3       banana           50552
# 4       banana           50552
# ...        ...             ...
# 240882     van             102
# 240883     van             102
# 240884     van             102
# 240885   clock             100
# 240886   clock             100
#
#                                                       def  \
# 0       elongated crescent-shaped yellow fruit with so...
# 1       elongated crescent-shaped yellow fruit with so...
# 2       elongated crescent-shaped yellow fruit with so...
# 3       elongated crescent-shaped yellow fruit with so...
# 4       elongated crescent-shaped yellow fruit with so...
# ...                                                   ...
# 240882  a recreational vehicle equipped for camping ou...
# 240883  a recreational vehicle equipped for camping ou...
# 240884  a recreational vehicle equipped for camping ou...
# 240885                          a clock mounted on a wall
# 240886                          a clock mounted on a wall
#
#                                            synonyms  image_count    id  \
# 0                                          [banana]         1787    45
# 1                                          [banana]         1787    45
# 2                                          [banana]         1787    45
# 3                                          [banana]         1787    45
# 4                                          [banana]         1787    45
# ...                                             ...          ...   ...
# 240882  [camper_(vehicle), camping_bus, motor_home]           40   191
# 240883  [camper_(vehicle), camping_bus, motor_home]           40   191
# 240884  [camper_(vehicle), camping_bus, motor_home]           40   191
# 240885                                 [wall_clock]           48  1154
# 240886                                 [wall_clock]           48  1154
#
#        frequency           synset  \
# 0              f      banana.n.02
# 1              f      banana.n.02
# 2              f      banana.n.02
# 3              f      banana.n.02
# 4              f      banana.n.02
# ...          ...              ...
# 240882         c      camper.n.02
# 240883         c      camper.n.02
# 240884         c      camper.n.02
# 240885         c  wall_clock.n.01
# 240886         c  wall_clock.n.01
#
#                                            original_class dataset  ...  \
# 0       {'original_class': 'banana', 'original_id': 45...    LVIS  ...
# 1       {'original_class': 'banana', 'original_id': 45...    LVIS  ...
# 2       {'original_class': 'banana', 'original_id': 45...    LVIS  ...
# 3       {'original_class': 'banana', 'original_id': 45...    LVIS  ...
# 4       {'original_class': 'banana', 'original_id': 45...    LVIS  ...
# ...                                                   ...     ...  ...
# 240882  {'original_class': 'camper_(vehicle)', 'origin...    LVIS  ...
# 240883  {'original_class': 'camper_(vehicle)', 'origin...    LVIS  ...
# 240884  {'original_class': 'camper_(vehicle)', 'origin...    LVIS  ...
# 240885  {'original_class': 'wall_clock', 'original_id'...    LVIS  ...
# 240886  {'original_class': 'wall_clock', 'original_id'...    LVIS  ...
#
#         image_id                             bbox        date_captured  \
# 0         480275   [344.41, 134.46, 21.78, 17.91]  2013-11-19 18:49:01
# 1         480275   [449.72, 128.35, 18.13, 14.72]  2013-11-19 18:49:01
# 2         480275   [355.56, 130.84, 41.34, 16.32]  2013-11-19 18:49:01
# 3         480275   [435.31, 127.72, 18.53, 20.48]  2013-11-19 18:49:01
# 4         480275    [297.86, 171.27, 10.15, 4.89]  2013-11-19 18:49:01
# ...          ...                              ...                  ...
# 240882    521221   [110.08, 33.53, 156.22, 59.73]  2013-11-15 21:57:58
# 240883    521221      [44.06, 45.0, 47.69, 22.51]  2013-11-15 21:57:58
# 240884    521221      [6.77, 54.61, 46.28, 21.82]  2013-11-15 21:57:58
# 240885    233139  [51.58, 172.71, 176.33, 173.26]  2013-11-24 11:49:20
# 240886    233139   [526.8, 202.91, 113.2, 139.86]  2013-11-24 11:49:20
#
#                                          neg_category_ids license height  \
# 0                   [29, 1128, 155, 36, 443, 68, 43, 895]       2    471
# 1                   [29, 1128, 155, 36, 443, 68, 43, 895]       2    471
# 2                   [29, 1128, 155, 36, 443, 68, 43, 895]       2    471
# 3                   [29, 1128, 155, 36, 443, 68, 43, 895]       2    471
# 4                   [29, 1128, 155, 36, 443, 68, 43, 895]       2    471
# ...                                                   ...     ...    ...
# 240882   [101, 501, 416, 591, 83, 31, 398, 491, 361, 252]       1    384
# 240883   [101, 501, 416, 591, 83, 31, 398, 491, 361, 252]       1    384
# 240884   [101, 501, 416, 591, 83, 31, 398, 491, 361, 252]       1    384
# 240885  [661, 369, 259, 737, 1006, 740, 1079, 33, 494,...       4    427
# 240886  [661, 369, 259, 737, 1006, 740, 1079, 33, 494,...       4    427
#
#        width                                         flickr_url  \
# 0        640  http://farm3.staticflickr.com/2740/4268400738_...
# 1        640  http://farm3.staticflickr.com/2740/4268400738_...
# 2        640  http://farm3.staticflickr.com/2740/4268400738_...
# 3        640  http://farm3.staticflickr.com/2740/4268400738_...
# 4        640  http://farm3.staticflickr.com/2740/4268400738_...
# ...      ...                                                ...
# 240882   640  http://farm7.staticflickr.com/6223/6231820585_...
# 240883   640  http://farm7.staticflickr.com/6223/6231820585_...
# 240884   640  http://farm7.staticflickr.com/6223/6231820585_...
# 240885   640  http://farm8.staticflickr.com/7012/6449253229_...
# 240886   640  http://farm8.staticflickr.com/7012/6449253229_...
#
#                                                  coco_url  \
# 0       http://images.cocodataset.org/val2017/00000048...
# 1       http://images.cocodataset.org/val2017/00000048...
# 2       http://images.cocodataset.org/val2017/00000048...
# 3       http://images.cocodataset.org/val2017/00000048...
# 4       http://images.cocodataset.org/val2017/00000048...
# ...                                                   ...
# 240882  http://images.cocodataset.org/train2017/000000...
# 240883  http://images.cocodataset.org/train2017/000000...
# 240884  http://images.cocodataset.org/train2017/000000...
# 240885  http://images.cocodataset.org/val2017/00000023...
# 240886  http://images.cocodataset.org/val2017/00000023...
#
#         not_exhaustive_category_ids
# 0                        [1152, 45]
# 1                        [1152, 45]
# 2                        [1152, 45]
# 3                        [1152, 45]
# 4                        [1152, 45]
# ...                             ...
# 240882                        [191]
# 240883                        [191]
# 240884                        [191]
# 240885                           []
# 240886                           []
#
# [240887 rows x 23 columns]

# %%
def extract_coco_filename(url):
    return url[-16:]

# %%
df_lvis["file_name"] = df_lvis["coco_url"].apply(extract_coco_filename)

# %%
coco_filename_not_in_lvis = list(set(df_coco["file_name"].values) - set(df_lvis["file_name"].values))
print(len(coco_filename_not_in_lvis))
# Out:
# 278

# %%
lvis_filename_not_in_coco = list(set(df_lvis["file_name"].values) - set(df_coco["file_name"].values))
print(len(lvis_filename_not_in_coco))
# Out:
# 14827

# %%
# Filtro COCO prendendo le classi non presenti in LVIS
df_coco = df_coco[(df_coco["name"].isin(unique_coco_classes))] #| (df_coco["file_name"].isin(coco_filename_not_in_lvis))]
len(set(df_coco["name"].values))
# Out:
# 43

# %%
df_coco["name"].value_counts()
# Out:
# wall          2363
# sky           1611
# tree          1407
# building       978
# grass          955
# floor          943
# pavement       873
# road           651
# window         602
# fence          554
# light          448
# dirt           444
# ceiling        415
# door           352
# plant          343
# sea            291
# remote         283
# house          277
# rug            266
# cell phone     262
# couch          261
# tie            254
# mountain       247
# laptop         231
# cardboard      229
# shelf          225
# sand           212
# rock           178
# snow           174
# roof           169
# furniture      162
# keyboard       153
# hot dog        127
# railroad       119
# platform       113
# gravel         113
# mouse          106
# staircase       92
# river           88
# bridge          87
# water           79
# tent            67
# net             53
# Name: name, dtype: int64

# %%
df_lvis["name"].value_counts()
# Out:
# banana      9156
# book        7022
# carrot      3762
# apple       3116
# pole        2913
#             ...
# eggplant       7
# sled           7
# cube           7
# windmill       5
# candy          3
# Name: name, Length: 521, dtype: int64

# %%
#df_lvis[df_lvis["name"]=="person"]

# %% [markdown]
# # ADE20K

# %%
f = open('./ade20k/ade_validation.json')
df_ade = pd.DataFrame(json.load(f))
df_ade
# Out:
#        id_annotations        name  \
# 0                   0         sky
# 1                   1        tree
# 2                   2        wall
# 3                   3    building
# 4                   4      dormer
# ...               ...         ...
# 70862              15       cliff
# 70863               1       stair
# 70864               2    platform
# 70865               3        wall
# 70866               4  grandstand
#
#                                           original_class dataset  \
# 0      {'original_class': 'sky', 'original_id': 0, 'd...  ADE20K
# 1      {'original_class': 'trees', 'original_id': 1, ...  ADE20K
# 2      {'original_class': 'wall', 'original_id': 2, '...  ADE20K
# 3      {'original_class': 'building', 'original_id': ...  ADE20K
# 4      {'original_class': 'dormer', 'original_id': 4,...  ADE20K
# ...                                                  ...     ...
# 70862  {'original_class': 'cliff', 'original_id': 15,...  ADE20K
# 70863  {'original_class': 'steps', 'original_id': 1, ...  ADE20K
# 70864  {'original_class': 'platform', 'original_id': ...  ADE20K
# 70865  {'original_class': 'wall', 'original_id': 3, '...  ADE20K
# 70866  {'original_class': 'grandstand', 'original_id'...  ADE20K
#
#                        bbox             file_name              image_id  \
# 0         [0, 0, 1278, 675]  ADE_val_00000001.jpg  ADE_val_00000001.jpg
# 1        [2, 577, 323, 735]  ADE_val_00000001.jpg  ADE_val_00000001.jpg
# 2        [0, 718, 654, 816]  ADE_val_00000001.jpg  ADE_val_00000001.jpg
# 3      [312, 87, 1275, 807]  ADE_val_00000001.jpg  ADE_val_00000001.jpg
# 4      [802, 477, 915, 561]  ADE_val_00000001.jpg  ADE_val_00000001.jpg
# ...                     ...                   ...                   ...
# 70862    [163, 0, 255, 256]  ADE_val_00001999.jpg  ADE_val_00001999.jpg
# 70863  [135, 193, 189, 239]  ADE_val_00002000.jpg  ADE_val_00002000.jpg
# 70864   [50, 165, 351, 261]  ADE_val_00002000.jpg  ADE_val_00002000.jpg
# 70865    [50, 38, 175, 181]  ADE_val_00002000.jpg  ADE_val_00002000.jpg
# 70866   [172, 37, 351, 172]  ADE_val_00002000.jpg  ADE_val_00002000.jpg
#
#                                             segmentation
# 0      [0, 0, 0, 588, 37, 588, 65, 588, 81, 604, 90, ...
# 1      [3, 683, 2, 584, 10, 583, 30, 583, 45, 577, 52...
# 2      [3, 816, 119, 808, 244, 809, 339, 801, 390, 80...
# 3      [760, 783, 654, 797, 653, 724, 322, 713, 312, ...
# 4      [861, 549, 915, 487, 854, 477, 802, 490, 808, ...
# ...                                                  ...
# 70862  [255, 0, 212, 0, 209, 2, 208, 8, 206, 9, 202, ...
# 70863  [162, 239, 189, 226, 185, 200, 158, 193, 153, ...
# 70864  [50, 261, 51, 182, 78, 170, 80, 192, 225, 233,...
# 70865  [50, 38, 172, 38, 175, 124, 175, 130, 175, 136...
# 70866  [349, 38, 172, 37, 175, 109, 181, 111, 181, 13...
#
# [70867 rows x 8 columns]

# %%
len(set(df_ade["file_name"]))
# Out:
# 2000

# %% [markdown]
# ## COCO

# %%
f = open('coco/instances_val2017.json')
 
coco_instances = json.load(f)
coco_annotations = pd.DataFrame(coco_instances["annotations"])
coco_images = pd.DataFrame(coco_instances["images"])
df_coco_instances = pd.merge(pd.DataFrame(coco_instances["categories"]).rename(columns={"id": "category_id"}),pd.merge(coco_annotations, coco_images.rename(columns={"id":"image_id"}), on="image_id"))
df_coco_instances[['x1','x2', 'x3', 'x4']] = pd.DataFrame(df_coco_instances.bbox.tolist(), index= df_coco_instances.index)

df_coco_instances
# Out:
#       supercategory  category_id        name  \
# 0            person            1      person
# 1            person            1      person
# 2            person            1      person
# 3            person            1      person
# 4            person            1      person
# ...             ...          ...         ...
# 36776        indoor           90  toothbrush
# 36777        indoor           90  toothbrush
# 36778        indoor           90  toothbrush
# 36779        indoor           90  toothbrush
# 36780        indoor           90  toothbrush
#
#                                             segmentation         area  \
# 0      [[204.01, 306.23, 206.07, 295.92, 216.38, 281....   5463.68640
# 1      [[236.03, 0.95, 311.02, 2.69, 335.44, 60.24, 3...  31093.79615
# 2      [[188.64, 407.23, 205.69, 337.82, 194.72, 290....  18491.31210
# 3      [[197.42, 429.52, 197.42, 413.46, 201.43, 402....  10359.75385
# 4      [[413.54, 311.35, 404.94, 263.6, 411.63, 201.5...  11052.97425
# ...                                                  ...          ...
# 36776  [[456.83, 219.44, 458.87, 179.74, 458.87, 164....   1462.50640
# 36777  [[151.94, 238.04, 160.62, 245.17, 161.24, 248....    827.46165
# 36778  [[2.77, 402.51, 38.1, 382.64, 55.76, 373.07, 7...  17372.48470
# 36779  [[245.64, 181.87, 248.23, 188.34, 246.94, 193....    411.22345
# 36780  [[151.92, 366.06, 155.74, 376.56, 159.08, 386....   1034.54920
#
#        iscrowd  image_id                             bbox       id  license  \
# 0            0    289343  [204.01, 235.08, 60.84, 177.36]   201376        2
# 1            0    579321    [94.78, 0.95, 240.66, 211.01]   203166        5
# 2            0    494869  [181.21, 88.17, 180.35, 347.61]   192257        1
# 3            0    494869  [197.42, 321.09, 91.36, 198.79]  2153738        1
# 4            0    554002   [403.99, 36.29, 59.21, 275.06]   218421        1
# ...        ...       ...                              ...      ...      ...
# 36776        0     55528   [447.67, 110.5, 26.47, 108.94]   342751        2
# 36777        0    324614  [151.63, 232.77, 123.14, 59.55]   342835        3
# 36778        0    521405     [0.0, 179.5, 305.27, 223.01]   342858        2
# 36779        0    563281    [233.03, 170.55, 30.08, 49.8]   343676        2
# 36780        0    445999   [139.51, 366.06, 39.62, 54.42]  1997161        3
#
#               file_name                                           coco_url  \
# 0      000000289343.jpg  http://images.cocodataset.org/val2017/00000028...
# 1      000000579321.jpg  http://images.cocodataset.org/val2017/00000057...
# 2      000000494869.jpg  http://images.cocodataset.org/val2017/00000049...
# 3      000000494869.jpg  http://images.cocodataset.org/val2017/00000049...
# 4      000000554002.jpg  http://images.cocodataset.org/val2017/00000055...
# ...                 ...                                                ...
# 36776  000000055528.jpg  http://images.cocodataset.org/val2017/00000005...
# 36777  000000324614.jpg  http://images.cocodataset.org/val2017/00000032...
# 36778  000000521405.jpg  http://images.cocodataset.org/val2017/00000052...
# 36779  000000563281.jpg  http://images.cocodataset.org/val2017/00000056...
# 36780  000000445999.jpg  http://images.cocodataset.org/val2017/00000044...
#
#        height  width        date_captured  \
# 0         640    529  2013-11-15 00:35:14
# 1         498    640  2013-11-14 17:38:30
# 2         640    427  2013-11-14 18:46:11
# 3         640    427  2013-11-14 18:46:11
# 4         425    640  2013-11-14 17:39:50
# ...       ...    ...                  ...
# 36776     480    640  2013-11-21 19:45:47
# 36777     427    640  2013-11-21 20:14:30
# 36778     640    426  2013-11-21 20:13:15
# 36779     500    489  2013-11-21 20:04:31
# 36780     640    411  2013-11-21 20:13:56
#
#                                               flickr_url      x1      x2  \
# 0      http://farm5.staticflickr.com/4029/4669549715_...  204.01  235.08
# 1      http://farm5.staticflickr.com/4114/4737904204_...   94.78    0.95
# 2      http://farm9.staticflickr.com/8255/8713396144_...  181.21   88.17
# 3      http://farm9.staticflickr.com/8255/8713396144_...  197.42  321.09
# 4      http://farm9.staticflickr.com/8292/7551688628_...  403.99   36.29
# ...                                                  ...     ...     ...
# 36776  http://farm3.staticflickr.com/2789/4125569884_...  447.67  110.50
# 36777  http://farm7.staticflickr.com/6153/6152986661_...  151.63  232.77
# 36778  http://farm5.staticflickr.com/4042/4435154720_...    0.00  179.50
# 36779  http://farm3.staticflickr.com/2416/2238628414_...  233.03  170.55
# 36780  http://farm5.staticflickr.com/4040/4584442075_...  139.51  366.06
#
#            x3      x4
# 0       60.84  177.36
# 1      240.66  211.01
# 2      180.35  347.61
# 3       91.36  198.79
# 4       59.21  275.06
# ...       ...     ...
# 36776   26.47  108.94
# 36777  123.14   59.55
# 36778  305.27  223.01
# 36779   30.08   49.80
# 36780   39.62   54.42
#
# [36781 rows x 20 columns]

# %%
f = open('coco/stuff_val2017.json')
 
coco_stuff = json.load(f)
coco_annotations_stuff = pd.DataFrame(coco_stuff["annotations"])
coco_images_stuff = pd.DataFrame(coco_stuff["images"])
df_coco_stuff = pd.merge(pd.DataFrame(coco_stuff["categories"]).rename(columns={"id": "category_id"}),pd.merge(coco_annotations_stuff, coco_images_stuff.rename(columns={"id":"image_id"}), on="image_id"))
#df_coco_stuff = df_coco_stuff[df_coco_stuff["name"]!="other"]
df_coco_stuff[['x1','x2', 'x3', 'x4']] = pd.DataFrame(df_coco_stuff.bbox.tolist(), index= df_coco_stuff.index)

df_coco_stuff
# Out:
#       supercategory  category_id    name  \
# 0           textile           92  banner
# 1           textile           92  banner
# 2           textile           92  banner
# 3           textile           92  banner
# 4           textile           92  banner
# ...             ...          ...     ...
# 32796         other          183   other
# 32797         other          183   other
# 32798         other          183   other
# 32799         other          183   other
# 32800         other          183   other
#
#                                             segmentation      area  iscrowd  \
# 0      {'counts': 'W1e0d0LT52lJNU51kJNW51iJOX5OiJ1W5O...    2505.0        0
# 1      {'counts': '0c0m0Q4Z7oKfHQ4Z7oKfHQ4Z7oKfHQ4Z7o...   50949.0        0
# 2      {'counts': 'XRf2;3FN61K020M0000P20`9Z1RFhNdN1Y...   18161.0        0
# 3      {'counts': 'h4l0`<1OM11001O000000`CWO\<0dCi00X...    1077.0        0
# 4      {'counts': 'mb^13o9OYF6c9MVFL0=f97N03L7G24001O...     337.0        0
# ...                                                  ...       ...      ...
# 32796  {'counts': 'oj\44l:5M2M3bEEQ:>kEFS:;kEF1Jn9P1O...   33969.0        0
# 32797  {'counts': 'fV<^1fa0g0YOI7O1kNR_O5m`0KT_O5l`0I...   26150.0        0
# 32798  {'counts': 'ZTY56k<=D=F9I7I7M3L4L2O1N1O2O1N1O2...    9544.0        0
# 32799  {'counts': 'oXg21nc0`0@?A?A?A`0@<D5K5K5K5K5K5K...   34106.0        0
# 32800  {'counts': 'TR16c50n2a0_LOS3b0hLAj2o0QMSOb2]1X...  116886.0        0
#
#        image_id                          bbox        id  license  \
# 0          5586      [0.0, 39.0, 320.0, 58.0]  20000299        2
# 1          8211      [0.0, 0.0, 613.0, 218.0]  20000479        3
# 2         22755    [184.0, 0.0, 166.0, 127.0]  20001355        1
# 3         26204      [0.0, 136.0, 35.0, 47.0]  20001564        3
# 4         33221     [143.0, 75.0, 26.0, 26.0]  20001974        3
# ...         ...                           ...       ...      ...
# 32796    581317   [407.0, 56.0, 206.0, 298.0]  20032778        5
# 32797    581357    [20.0, 93.0, 572.0, 385.0]  20032786        3
# 32798    581482  [405.0, 205.0, 140.0, 114.0]  20032791        4
# 32799    581615  [139.0, 386.0, 192.0, 235.0]  20032795        4
# 32800    581781      [2.0, 0.0, 638.0, 457.0]  20032800        1
#
#               file_name                                           coco_url  \
# 0      000000005586.jpg  http://images.cocodataset.org/val2017/00000000...
# 1      000000008211.jpg  http://images.cocodataset.org/val2017/00000000...
# 2      000000022755.jpg  http://images.cocodataset.org/val2017/00000002...
# 3      000000026204.jpg  http://images.cocodataset.org/val2017/00000002...
# 4      000000033221.jpg  http://images.cocodataset.org/val2017/00000003...
# ...                 ...                                                ...
# 32796  000000581317.jpg  http://images.cocodataset.org/val2017/00000058...
# 32797  000000581357.jpg  http://images.cocodataset.org/val2017/00000058...
# 32798  000000581482.jpg  http://images.cocodataset.org/val2017/00000058...
# 32799  000000581615.jpg  http://images.cocodataset.org/val2017/00000058...
# 32800  000000581781.jpg  http://images.cocodataset.org/val2017/00000058...
#
#        height  width        date_captured  \
# 0         240    320  2013-11-23 03:22:07
# 1         459    640  2013-11-15 14:44:03
# 2         479    640  2013-11-16 17:20:29
# 3         427    640  2013-11-16 13:56:51
# 4         333    500  2013-11-21 01:43:55
# ...       ...    ...                  ...
# 32796     354    640  2013-11-24 07:57:55
# 32797     612    612  2013-11-19 23:24:10
# 32798     427    640  2013-11-24 13:25:09
# 32799     640    478  2013-11-15 15:25:51
# 32800     478    640  2013-11-19 19:14:20
#
#                                               flickr_url     x1     x2     x3  \
# 0      http://farm4.staticflickr.com/3488/3468455810_...    0.0   39.0  320.0
# 1      http://farm5.staticflickr.com/4103/5055051223_...    0.0    0.0  613.0
# 2      http://farm9.staticflickr.com/8101/8597825681_...  184.0    0.0  166.0
# 3      http://farm9.staticflickr.com/8419/8964746313_...    0.0  136.0   35.0
# 4      http://farm1.staticflickr.com/146/420740869_29...  143.0   75.0   26.0
# ...                                                  ...    ...    ...    ...
# 32796  http://farm1.staticflickr.com/14/19721466_b561...  407.0   56.0  206.0
# 32797  http://farm9.staticflickr.com/8203/8258620491_...   20.0   93.0  572.0
# 32798  http://farm6.staticflickr.com/5455/9400924184_...  405.0  205.0  140.0
# 32799  http://farm4.staticflickr.com/3136/5859483600_...  139.0  386.0  192.0
# 32800  http://farm6.staticflickr.com/5068/5883211700_...    2.0    0.0  638.0
#
#           x4
# 0       58.0
# 1      218.0
# 2      127.0
# 3       47.0
# 4       26.0
# ...      ...
# 32796  298.0
# 32797  385.0
# 32798  114.0
# 32799  235.0
# 32800  457.0
#
# [32801 rows x 20 columns]

# %%
f = open('coco/panoptic_val2017.json')
 
coco_panoptic = json.load(f)

# %%
coco_panoptic.keys()
# Out:
# dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %%
new_coco_panoptic = list()
for elem in coco_panoptic["annotations"]:
    for seg in elem["segments_info"]:
        segment = seg
        segment["file_name"]=elem["file_name"].replace("png", "jpg")
        segment["image_id"]=elem["image_id"]
        segment["x1"]=segment["bbox"][0]
        segment["x2"]=segment["bbox"][1]
        segment["x3"]=segment["bbox"][2]
        segment["x4"]=segment["bbox"][3]
        new_coco_panoptic.append(segment)

# %%
df_coco_panoptic = pd.merge(pd.DataFrame(new_coco_panoptic), pd.DataFrame(coco_panoptic["categories"]).rename(columns={"id": "category_id"}), on=["category_id"])
df_coco_panoptic
# Out:
#              id  category_id  iscrowd                  bbox   area  \
# 0       3226956            1        0   [413, 158, 53, 138]   2840
# 1       6979964            1        0    [384, 172, 16, 36]    439
# 2       3287629            1        0   [281, 45, 216, 346]  27486
# 3      12234672            1        0  [164, 126, 265, 481]  47692
# 4       8620683            1        0  [145, 101, 292, 457]  25073
# ...         ...          ...      ...                   ...    ...
# 56723   8750473           89        0    [0, 102, 164, 181]  22522
# 56724   3359042           89        0   [316, 188, 83, 226]   5068
# 56725   5869770           89        0     [140, 49, 29, 38]    594
# 56726   5057040           89        0     [156, 25, 34, 20]    299
# 56727   3419691           89        0  [195, 210, 144, 228]   9639
#
#               file_name  image_id   x1   x2   x3   x4 supercategory  isthing  \
# 0      000000000139.jpg       139  413  158   53  138        person        1
# 1      000000000139.jpg       139  384  172   16   36        person        1
# 2      000000000785.jpg       785  281   45  216  346        person        1
# 3      000000000872.jpg       872  164  126  265  481        person        1
# 4      000000000872.jpg       872  145  101  292  457        person        1
# ...                 ...       ...  ...  ...  ...  ...           ...      ...
# 56723  000000350002.jpg    350002    0  102  164  181        indoor        1
# 56724  000000384136.jpg    384136  316  188   83  226        indoor        1
# 56725  000000500464.jpg    500464  140   49   29   38        indoor        1
# 56726  000000501368.jpg    501368  156   25   34   20        indoor        1
# 56727  000000569976.jpg    569976  195  210  144  228        indoor        1
#
#              name
# 0          person
# 1          person
# 2          person
# 3          person
# 4          person
# ...           ...
# 56723  hair drier
# 56724  hair drier
# 56725  hair drier
# 56726  hair drier
# 56727  hair drier
#
# [56728 rows x 14 columns]

# %%
df_coco_panoptic[df_coco_panoptic["category_id"]==186]
# Out:
#              id  category_id  iscrowd                bbox    area  \
# 17540   6266027          186        0  [136, 0, 473, 116]   20106
# 17541   4541265          186        0    [15, 0, 409, 79]   29548
# 17542   4874096          186        0    [0, 0, 375, 110]   31666
# 17543    930899          186        0     [0, 0, 640, 54]   28665
# 17544  10988721          186        0    [407, 0, 73, 54]    3317
# ...         ...          ...      ...                 ...     ...
# 17951   6711921          186        0    [0, 0, 526, 292]  123902
# 17952   9016744          186        0   [16, 0, 469, 116]   23145
# 17953   4473651          186        0   [155, 0, 333, 56]   13764
# 17954  12962506          186        0     [0, 0, 427, 71]   21348
# 17955   1579032          186        0  [109, 0, 531, 205]   36420
#
#               file_name  image_id   x1  x2   x3   x4 supercategory  isthing  \
# 17540  000000000139.jpg       139  136   0  473  116       ceiling        0
# 17541  000000000802.jpg       802   15   0  409   79       ceiling        0
# 17542  000000003934.jpg      3934    0   0  375  110       ceiling        0
# 17543  000000004134.jpg      4134    0   0  640   54       ceiling        0
# 17544  000000005060.jpg      5060  407   0   73   54       ceiling        0
# ...                 ...       ...  ...  ..  ...  ...           ...      ...
# 17951  000000578093.jpg    578093    0   0  526  292       ceiling        0
# 17952  000000578500.jpg    578500   16   0  469  116       ceiling        0
# 17953  000000579970.jpg    579970  155   0  333   56       ceiling        0
# 17954  000000580410.jpg    580410    0   0  427   71       ceiling        0
# 17955  000000581482.jpg    581482  109   0  531  205       ceiling        0
#
#                  name
# 17540  ceiling-merged
# 17541  ceiling-merged
# 17542  ceiling-merged
# 17543  ceiling-merged
# 17544  ceiling-merged
# ...               ...
# 17951  ceiling-merged
# 17952  ceiling-merged
# 17953  ceiling-merged
# 17954  ceiling-merged
# 17955  ceiling-merged
#
# [416 rows x 14 columns]

# %%
df_coco_stuff[df_coco_stuff["category_id"]==102]
# Out:
#      supercategory  category_id           name  \
# 2776       ceiling          102  ceiling-other
# 2777       ceiling          102  ceiling-other
# 2778       ceiling          102  ceiling-other
# 2779       ceiling          102  ceiling-other
# 2780       ceiling          102  ceiling-other
# ...            ...          ...            ...
# 3178       ceiling          102  ceiling-other
# 3179       ceiling          102  ceiling-other
# 3180       ceiling          102  ceiling-other
# 3181       ceiling          102  ceiling-other
# 3182       ceiling          102  ceiling-other
#
#                                            segmentation      area  iscrowd  \
# 2776  {'counts': '`bh11Y=1O1O1O1O001O001O001O001O001...   20106.0        0
# 2777  {'counts': 'P\98hc0b0a\OXObb0j1YO2N1O000000000...   29548.0        0
# 2778  {'counts': '0k0i>N2N23M2N1O2N1O3M2N00002cAkNW>...   31666.0        0
# 2779  {'counts': '0l0]<00002NO1O10000001O3M00001O000...   28665.0        0
# 2780  {'counts': 'i\n72hc07N6I3O1N1N200C[O^]Of0bb0_O...    3317.0        0
# ...                                                 ...       ...      ...
# 3178  {'counts': '0h7X71O^Ob000000000001O00000000000...  123902.0        0
# 3179  {'counts': 'Qa4414c8601O00001O001O000000001O00...   23145.0        0
# 3180  {'counts': 'Plb11]:5M2M2O2AHZF01;d9<O00003M2N1...   13764.0        0
# 3181  {'counts': '0n1Rb000001O1O001O001O1O001OO11O00...   21348.0        0
# 3182  {'counts': 'fb]12Y=001O1INRC3m<6KFYC9g<7NO0101...   36420.0        0
#
#       image_id                        bbox        id  license  \
# 2776       139  [136.0, 0.0, 473.0, 116.0]  20000001        2
# 2777       802    [15.0, 0.0, 409.0, 79.0]  20000032        6
# 2778      3934    [0.0, 0.0, 375.0, 110.0]  20000216        1
# 2779      4134     [0.0, 0.0, 640.0, 54.0]  20000226        6
# 2780      5060    [407.0, 0.0, 73.0, 54.0]  20000265        1
# ...        ...                         ...       ...      ...
# 3178    578093    [0.0, 0.0, 526.0, 292.0]  20032583        1
# 3179    578500   [16.0, 0.0, 469.0, 116.0]  20032599        4
# 3180    579970   [155.0, 0.0, 333.0, 56.0]  20032699        6
# 3181    580410     [0.0, 0.0, 427.0, 71.0]  20032727        3
# 3182    581482  [109.0, 0.0, 531.0, 205.0]  20032787        4
#
#              file_name                                           coco_url  \
# 2776  000000000139.jpg  http://images.cocodataset.org/val2017/00000000...
# 2777  000000000802.jpg  http://images.cocodataset.org/val2017/00000000...
# 2778  000000003934.jpg  http://images.cocodataset.org/val2017/00000000...
# 2779  000000004134.jpg  http://images.cocodataset.org/val2017/00000000...
# 2780  000000005060.jpg  http://images.cocodataset.org/val2017/00000000...
# ...                ...                                                ...
# 3178  000000578093.jpg  http://images.cocodataset.org/val2017/00000057...
# 3179  000000578500.jpg  http://images.cocodataset.org/val2017/00000057...
# 3180  000000579970.jpg  http://images.cocodataset.org/val2017/00000057...
# 3181  000000580410.jpg  http://images.cocodataset.org/val2017/00000058...
# 3182  000000581482.jpg  http://images.cocodataset.org/val2017/00000058...
#
#       height  width        date_captured  \
# 2776     426    640  2013-11-21 01:34:01
# 2777     640    424  2013-11-24 10:59:09
# 2778     500    375  2013-11-21 21:11:39
# 2779     425    640  2013-11-18 02:54:21
# 2780     640    480  2013-11-24 05:50:52
# ...      ...    ...                  ...
# 3178     480    640  2013-11-17 08:36:24
# 3179     290    640  2013-11-22 00:59:44
# 3180     336    500  2013-11-22 01:52:53
# 3181     640    427  2013-11-22 01:20:06
# 3182     427    640  2013-11-24 13:25:09
#
#                                              flickr_url     x1   x2     x3  \
# 2776  http://farm9.staticflickr.com/8035/8024364858_...  136.0  0.0  473.0
# 2777  http://farm5.staticflickr.com/4031/4430589002_...   15.0  0.0  409.0
# 2778  http://farm4.staticflickr.com/3429/3315867532_...    0.0  0.0  375.0
# 2779  http://farm9.staticflickr.com/8154/6988791438_...    0.0  0.0  640.0
# 2780  http://farm3.staticflickr.com/2672/3715883304_...  407.0  0.0   73.0
# ...                                                 ...    ...  ...    ...
# 3178  http://farm4.staticflickr.com/3688/9237520735_...    0.0  0.0  526.0
# 3179  http://farm5.staticflickr.com/4042/4376919410_...   16.0  0.0  469.0
# 3180  http://farm4.staticflickr.com/3513/3840928054_...  155.0  0.0  333.0
# 3181  http://farm3.staticflickr.com/2582/4136717151_...    0.0  0.0  427.0
# 3182  http://farm6.staticflickr.com/5455/9400924184_...  109.0  0.0  531.0
#
#          x4
# 2776  116.0
# 2777   79.0
# 2778  110.0
# 2779   54.0
# 2780   54.0
# ...     ...
# 3178  292.0
# 3179  116.0
# 3180   56.0
# 3181   71.0
# 3182  205.0
#
# [407 rows x 20 columns]

# %%
df_coco_instances[df_coco_instances["image_id"]==1296]
# Out:
#       supercategory  category_id        name  \
# 10518        person            1      person
# 10519        person            1      person
# 34173    electronic           77  cell phone
# 36110        indoor           85       clock
#
#                                             segmentation          area  \
# 10518  [[313.56, 243.54, 323.58, 260.72, 337.9, 247.8...  193582.61740
# 10519  [[270.54, 37.96, 291.08, 28.48, 327.43, 25.32,...   14101.57940
# 34173  [[301.68, 160.38, 299.46, 226.92, 307.6, 236.5...    7653.48970
# 36110  [[371.53, 411.26, 385.14, 408.26, 389.06, 421....     207.38825
#
#        iscrowd  image_id                             bbox       id  license  \
# 10518        0      1296     [7.16, 1.57, 419.84, 634.27]   470530        5
# 10519        0      1296  [262.64, 25.32, 146.96, 213.33]  1740912        5
# 34173        0      1296   [299.46, 143.38, 71.72, 135.3]   324614        5
# 36110        0      1296   [371.53, 408.26, 17.53, 16.61]   334018        5
#
#               file_name                                           coco_url  \
# 10518  000000001296.jpg  http://images.cocodataset.org/val2017/00000000...
# 10519  000000001296.jpg  http://images.cocodataset.org/val2017/00000000...
# 34173  000000001296.jpg  http://images.cocodataset.org/val2017/00000000...
# 36110  000000001296.jpg  http://images.cocodataset.org/val2017/00000000...
#
#        height  width        date_captured  \
# 10518     640    427  2013-11-24 08:22:26
# 10519     640    427  2013-11-24 08:22:26
# 34173     640    427  2013-11-24 08:22:26
# 36110     640    427  2013-11-24 08:22:26
#
#                                               flickr_url      x1      x2  \
# 10518  http://farm5.staticflickr.com/4010/4690487654_...    7.16    1.57
# 10519  http://farm5.staticflickr.com/4010/4690487654_...  262.64   25.32
# 34173  http://farm5.staticflickr.com/4010/4690487654_...  299.46  143.38
# 36110  http://farm5.staticflickr.com/4010/4690487654_...  371.53  408.26
#
#            x3      x4
# 10518  419.84  634.27
# 10519  146.96  213.33
# 34173   71.72  135.30
# 36110   17.53   16.61

# %%
df_coco_panoptic[df_coco_panoptic["image_id"]==1296]
# Out:
#              id  category_id  iscrowd                 bbox    area  \
# 29      2698051            1        0  [263, 25, 146, 213]   14098
# 30      6185598            1        0     [7, 2, 420, 634]  192000
# 15437   3355192           85        0   [372, 408, 17, 17]     207
# 34738  12168132           77        0  [299, 143, 72, 135]    7653
#
#               file_name  image_id   x1   x2   x3   x4 supercategory  isthing  \
# 29     000000001296.jpg      1296  263   25  146  213        person        1
# 30     000000001296.jpg      1296    7    2  420  634        person        1
# 15437  000000001296.jpg      1296  372  408   17   17        indoor        1
# 34738  000000001296.jpg      1296  299  143   72  135    electronic        1
#
#              name
# 29         person
# 30         person
# 15437       clock
# 34738  cell phone

# %%
df_coco_stuff[df_coco_stuff["image_id"]==1296]
# Out:
#       supercategory  category_id     name  \
# 3321        textile          105  clothes
# 27860         other          183    other
#
#                                             segmentation      area  iscrowd  \
# 3321   {'counts': 'mkZ33ic04O100000000000000000000001...    1458.0        0
# 27860  {'counts': 'Zh4a0[c0i1WN<E6I7I7I7I7I7L3M4M3L4L...  213958.0        0
#
#        image_id                        bbox        id  license  \
# 3321       1296  [170.0, 632.0, 257.0, 8.0]  20000070        5
# 27860      1296    [7.0, 2.0, 420.0, 634.0]  20000071        5
#
#               file_name                                           coco_url  \
# 3321   000000001296.jpg  http://images.cocodataset.org/val2017/00000000...
# 27860  000000001296.jpg  http://images.cocodataset.org/val2017/00000000...
#
#        height  width        date_captured  \
# 3321      640    427  2013-11-24 08:22:26
# 27860     640    427  2013-11-24 08:22:26
#
#                                               flickr_url     x1     x2     x3  \
# 3321   http://farm5.staticflickr.com/4010/4690487654_...  170.0  632.0  257.0
# 27860  http://farm5.staticflickr.com/4010/4690487654_...    7.0    2.0  420.0
#
#           x4
# 3321     8.0
# 27860  634.0

# %%
df_coco_stuff_finale = pd.merge(df_coco_panoptic, df_coco_stuff[["supercategory", "category_id", "name", "segmentation", "image_id", "id", "file_name", "height", "width", "x1", "x2", "x3", "x4", "bbox"]].rename(columns={"bbox": "bbox_stuff", "id":"segmentation_id", "name" : "name_stuff", "supercategory": "supercategory_stuff", "file_name": "filename_stuff", "category_id": "category_id_stuff"}), on=["image_id", "x1", "x2", "x3", "x4"])

df_coco_stuff_finale

# %%
set(df_coco_panoptic[df_coco_panoptic["isthing"]==0]["name"])
# Out:
# {'banner',
#  'blanket',
#  'bridge',
#  'building-other-merged',
#  'cabinet-merged',
#  'cardboard',
#  'ceiling-merged',
#  'counter',
#  'curtain',
#  'dirt-merged',
#  'door-stuff',
#  'fence-merged',
#  'floor-other-merged',
#  'floor-wood',
#  'flower',
#  'food-other-merged',
#  'fruit',
#  'grass-merged',
#  'gravel',
#  'house',
#  'light',
#  'mirror-stuff',
#  'mountain-merged',
#  'net',
#  'paper-merged',
#  'pavement-merged',
#  'pillow',
#  'platform',
#  'playingfield',
#  'railroad',
#  'river',
#  'road',
#  'rock-merged',
#  'roof',
#  'rug-merged',
#  'sand',
#  'sea',
#  'shelf',
#  'sky-other-merged',
#  'snow',
#  'stairs',
#  'table-merged',
#  'tent',
#  'towel',
#  'tree-merged',
#  'wall-brick',
#  'wall-other-merged',
#  'wall-stone',
#  'wall-tile',
#  'wall-wood',
#  'water-other',
#  'window-blind',
#  'window-other'}

# %%
len(set(df_coco_stuff_finale["name"].values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\GABRIE~1.FER\AppData\Local\Temp/ipykernel_7252/172155757.py in <module>
# ----> 1 len(set(df_coco_stuff_finale["name"].values))
#
# NameError: name 'df_coco_stuff_finale' is not defined

# %%
df_coco_stuff[["supercategory", "category_id", "name", "segmentation", "image_id", "id", "file_name", "height", "width", "x1", "x2", "x3", "x4"]].rename(columns={"id":"segmentation_id"})
# Out:
#       supercategory  category_id    name  \
# 0           textile           92  banner
# 1           textile           92  banner
# 2           textile           92  banner
# 3           textile           92  banner
# 4           textile           92  banner
# ...             ...          ...     ...
# 32796         other          183   other
# 32797         other          183   other
# 32798         other          183   other
# 32799         other          183   other
# 32800         other          183   other
#
#                                             segmentation  image_id  \
# 0      {'counts': 'W1e0d0LT52lJNU51kJNW51iJOX5OiJ1W5O...      5586
# 1      {'counts': '0c0m0Q4Z7oKfHQ4Z7oKfHQ4Z7oKfHQ4Z7o...      8211
# 2      {'counts': 'XRf2;3FN61K020M0000P20`9Z1RFhNdN1Y...     22755
# 3      {'counts': 'h4l0`<1OM11001O000000`CWO\<0dCi00X...     26204
# 4      {'counts': 'mb^13o9OYF6c9MVFL0=f97N03L7G24001O...     33221
# ...                                                  ...       ...
# 32796  {'counts': 'oj\44l:5M2M3bEEQ:>kEFS:;kEF1Jn9P1O...    581317
# 32797  {'counts': 'fV<^1fa0g0YOI7O1kNR_O5m`0KT_O5l`0I...    581357
# 32798  {'counts': 'ZTY56k<=D=F9I7I7M3L4L2O1N1O2O1N1O2...    581482
# 32799  {'counts': 'oXg21nc0`0@?A?A?A`0@<D5K5K5K5K5K5K...    581615
# 32800  {'counts': 'TR16c50n2a0_LOS3b0hLAj2o0QMSOb2]1X...    581781
#
#        segmentation_id         file_name  height  width     x1     x2     x3  \
# 0             20000299  000000005586.jpg     240    320    0.0   39.0  320.0
# 1             20000479  000000008211.jpg     459    640    0.0    0.0  613.0
# 2             20001355  000000022755.jpg     479    640  184.0    0.0  166.0
# 3             20001564  000000026204.jpg     427    640    0.0  136.0   35.0
# 4             20001974  000000033221.jpg     333    500  143.0   75.0   26.0
# ...                ...               ...     ...    ...    ...    ...    ...
# 32796         20032778  000000581317.jpg     354    640  407.0   56.0  206.0
# 32797         20032786  000000581357.jpg     612    612   20.0   93.0  572.0
# 32798         20032791  000000581482.jpg     427    640  405.0  205.0  140.0
# 32799         20032795  000000581615.jpg     640    478  139.0  386.0  192.0
# 32800         20032800  000000581781.jpg     478    640    2.0    0.0  638.0
#
#           x4
# 0       58.0
# 1      218.0
# 2      127.0
# 3       47.0
# 4       26.0
# ...      ...
# 32796  298.0
# 32797  385.0
# 32798  114.0
# 32799  235.0
# 32800  457.0
#
# [32801 rows x 13 columns]

# %%
# final df 
df_coco = df_coco_panoptic.merge(df_stuff, on=['image_id', "x1", "x2", "x3", "x4"])[["id","category_id", "bbox","area_x", "file_name", "image_id", "segmentation","category_id_stuff","id_stuff"]].rename(columns={"area_x": "area"})
df_coco = pd.concat([df_coco, df_things]).sort_values(by=['image_id',"category_id"])
df_coco
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\GABRIE~1.FER\AppData\Local\Temp/ipykernel_7252/1796873369.py in <module>
#       1 # final df
# ----> 2 df_coco = df_coco_panoptic.merge(df_stuff, on=['image_id', "x1", "x2", "x3", "x4"])[["id","category_id", "bbox","area_x", "file_name", "image_id", "segmentation","category_id_stuff","id_stuff"]].rename(columns={"area_x": "area"})
#       3 df_coco = pd.concat([df_coco, df_things]).sort_values(by=['image_id',"category_id"])
#       4 df_coco
#
# NameError: name 'df_stuff' is not defined
