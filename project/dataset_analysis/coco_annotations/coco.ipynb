# %%
import json
import pandas as pd

# %%
f = open('coco_annotations_t1.json')

t1 = json.load(f)
t1 = pd.DataFrame(t1)
t1
# Out:
#        supercategory  category_id    name   count  isthing  \
# 0             person            1  person  262351      NaN
# 1             person            1  person  262351      NaN
# 2             person            1  person  262351      NaN
# 3             person            1  person  262351      NaN
# 4             person            1  person  262351      NaN
# ...              ...          ...     ...     ...      ...
# 219508        person            1  person  262351      NaN
# 219509        person            1  person  262351      NaN
# 219510        person            1  person  262351      NaN
# 219511        person            1  person  262351      NaN
# 219512        person            1  person  262351      NaN
#
#                                            original_class dataset       id  \
# 0       {'original_class': 'person', 'original_id': 1,...    COCO   453991
# 1       {'original_class': 'person', 'original_id': 1,...    COCO   198565
# ...

# %%
f = open('coco_annotations_t2.json')
 
t2 = json.load(f)
t2 = pd.DataFrame(t2)
t2
# Out:
#        supercategory  category_id    name   count  isthing  \
# 0             person            1  person  262351      NaN
# 1             person            1  person  262351      NaN
# 2             person            1  person  262351      NaN
# 3             person            1  person  262351      NaN
# 4             person            1  person  262351      NaN
# ...              ...          ...     ...     ...      ...
# 219508        indoor           84    book   24692      NaN
# 219509        indoor           84    book   24692      NaN
# 219510        indoor           84    book   24692      NaN
# 219511        indoor           84    book   24692      NaN
# 219512        indoor           84    book   24692      NaN
#
#                                            original_class dataset       id  \
# 0       {'original_class': 'person', 'original_id': 1,...    COCO  1210591
# 1       {'original_class': 'person', 'original_id': 1,...    COCO  1246419
# ...

# %%
f = open('coco_annotations_t3.json')
 
t3 = json.load(f)
t3 = pd.DataFrame(t3)
t3
# Out:
#        supercategory  category_id           name  count  isthing  \
# 0             indoor           84           book  24692      NaN
# 1             indoor           84           book  24692      NaN
# 2             indoor           84           book  24692      NaN
# 3             indoor           84           book  24692      NaN
# 4             indoor           84           book  24692      NaN
# ...              ...          ...            ...    ...      ...
# 219508       outdoor           10  traffic light  12882      NaN
# 219509       outdoor           10  traffic light  12882      NaN
# 219510       outdoor           10  traffic light  12882      NaN
# 219511       outdoor           10  traffic light  12882      NaN
# 219512       outdoor           10  traffic light  12882      NaN
#
#                                            original_class dataset       id  \
# 0       {'original_class': 'book', 'original_id': 84, ...    COCO  1663222
# ...

# %%
f = open('coco_annotations_t4.json')
 
t4 = json.load(f)
t4 = pd.DataFrame(t4)
t4
# Out:
#        supercategory  category_id           name  count  isthing  \
# 0            outdoor           10  traffic light  12882      NaN
# 1            outdoor           10  traffic light  12882      NaN
# 2            outdoor           10  traffic light  12882      NaN
# 3            outdoor           10  traffic light  12882      NaN
# 4            outdoor           10  traffic light  12882      NaN
# ...              ...          ...            ...    ...      ...
# 219508    electronic           77     cell phone   6409      NaN
# 219509    electronic           77     cell phone   6409      NaN
# 219510    electronic           77     cell phone   6409      NaN
# 219511    electronic           77     cell phone   6409      NaN
# 219512    electronic           77     cell phone   6409      NaN
#
#                                            original_class dataset       id  \
# 0       {'original_class': 'traffic light', 'original_...    COCO   402965
# ...

# %%
f = open('coco_annotations_t5.json')
 
t5 = json.load(f)
t5 = pd.DataFrame(t5)
t5
# Out:
#        supercategory  category_id        name  count  isthing  \
# 0         electronic           77  cell phone   6409      NaN
# 1         electronic           77  cell phone   6409      NaN
# 2         electronic           77  cell phone   6409      NaN
# 3         electronic           77  cell phone   6409      NaN
# 4         electronic           77  cell phone   6409      NaN
# ...              ...          ...         ...    ...      ...
# 219508        indoor           89  hair dryer    198      NaN
# 219509        indoor           89  hair dryer    198      NaN
# 219510        indoor           89  hair dryer    198      NaN
# 219511        indoor           89  hair dryer    198      NaN
# 219512        indoor           89  hair dryer    198      NaN
#
#                                            original_class dataset       id  \
# 0       {'original_class': 'cell phone', 'original_id'...    COCO   322568
# ...

# %%
t = t1.append([t2, t3, t4, t5], ignore_index=True)

# %%
t
# Out:
#         supercategory  category_id        name   count  isthing  \
# 0              person            1      person  262351      NaN
# 1              person            1      person  262351      NaN
# 2              person            1      person  262351      NaN
# 3              person            1      person  262351      NaN
# 4              person            1      person  262351      NaN
# ...               ...          ...         ...     ...      ...
# 1097560        indoor           89  hair dryer     198      NaN
# 1097561        indoor           89  hair dryer     198      NaN
# 1097562        indoor           89  hair dryer     198      NaN
# 1097563        indoor           89  hair dryer     198      NaN
# 1097564        indoor           89  hair dryer     198      NaN
#
#                                             original_class dataset       id  \
# 0        {'original_class': 'person', 'original_id': 1,...    COCO   453991
# ...

# %%
f = open('coco_annotations_final.json', 'w')
json.dump(t.to_dict('records'), f)

# %%
f = open('coco_annotations_final.json')
 
df_coco = json.load(f)
df_coco = pd.DataFrame(df_coco)
df_coco
# Out:
#         supercategory  category_id        name   count  isthing  \
# 0              person            1      person  262351      NaN
# 1              person            1      person  262351      NaN
# 2              person            1      person  262351      NaN
# 3              person            1      person  262351      NaN
# 4              person            1      person  262351      NaN
# ...               ...          ...         ...     ...      ...
# 1097560        indoor           89  hair dryer     198      NaN
# 1097561        indoor           89  hair dryer     198      NaN
# 1097562        indoor           89  hair dryer     198      NaN
# 1097563        indoor           89  hair dryer     198      NaN
# 1097564        indoor           89  hair dryer     198      NaN
#
#                                             original_class dataset       id  \
# 0        {'original_class': 'person', 'original_id': 1,...    COCO   453991
# ...

# %%
#f = open('../coco/coco_annotations_tmp.json')

#df_coco_old = json.load(f)
#df_coco_old = pd.DataFrame(df_coco_old)
#df_coco_old

# %%
f = open('t1.json')

t1 = json.load(f)
t1 = pd.DataFrame(t1)

f = open('t2.json')

t2 = json.load(f)
t2 = pd.DataFrame(t2)

f = open('t3.json')

t3 = json.load(f)
t3 = pd.DataFrame(t3)

f = open('t4.json')

t4 = json.load(f)
t4 = pd.DataFrame(t4)

f = open('t5.json')

t5 = json.load(f)
t5 = pd.DataFrame(t5)

# %%
t = t1.append([t2, t3, t4, t5], ignore_index=True)

# %%
t
# Out:
# Index(['supercategory', 'category_id', 'name', 'count', 'isthing',
#        'original_class', 'dataset', 'id', 'bbox', 'area', 'file_name',
#        'image_id', 'segmentation', 'category_id_stuff', 'id_stuff', 'iscrowd',
#        'index', 'split'],
#       dtype='object')

# %%
t[['supercategory', 'category_id', 'name', 'count', 'isthing',
       'original_class', 'dataset', 'id', 'bbox', 'area', 'file_name',
       'image_id', 'category_id_stuff', 'id_stuff', 'iscrowd',
       'index', 'split']].equals(df_coco[['supercategory', 'category_id', 'name', 'count', 'isthing',
       'original_class', 'dataset', 'id', 'bbox', 'area', 'file_name',
       'image_id', 'category_id_stuff', 'id_stuff', 'iscrowd',
       'index', 'split']])
# Out:
# True
