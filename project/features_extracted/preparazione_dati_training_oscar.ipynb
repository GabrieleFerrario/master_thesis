# %%
import pandas as pd
import json
import os
from maskrcnn_benchmark.structures.tsv_file_ops import tsv_reader, tsv_writer
import yaml
import os.path as op
from shutil import copyfile
from tqdm import tqdm

# %%
sg_tsv = './train.hw.tsv'
df_train_hw = pd.read_csv(sg_tsv,sep='\t',header = None,converters={1:json.loads})#converters={1:ast.literal_eval})
print("Numero di immagini: {}".format(len(df_train_hw)))
# Out:
# Numero di immagini: 29000

# %%
df_train_hw["file"] = df_train_hw[0].apply(lambda x: str(x)+".csv")

# %%
df_train_hw
# Out:
#                 0                                1            file
# 0      1000092795  [{'height': 500, 'width': 333}]  1000092795.csv
# 1        10002456  [{'height': 374, 'width': 500}]    10002456.csv
# 2      1000268201  [{'height': 500, 'width': 375}]  1000268201.csv
# 3      1000344755  [{'height': 333, 'width': 500}]  1000344755.csv
# 4      1000366164  [{'height': 375, 'width': 500}]  1000366164.csv
# ...           ...                              ...             ...
# 28995   997338199  [{'height': 400, 'width': 500}]   997338199.csv
# 28996   997722733  [{'height': 500, 'width': 333}]   997722733.csv
# 28997   997876722  [{'height': 500, 'width': 333}]   997876722.csv
# 28998    99804383  [{'height': 500, 'width': 375}]    99804383.csv
# 28999   998845445  [{'height': 375, 'width': 500}]   998845445.csv
#
# [29000 rows x 3 columns]

# %%
f1 = os.listdir("./features_1")

# %%
f2 = os.listdir("./features_2")

# %%
f3 = os.listdir("./features_3")

# %%
f4 = os.listdir("./features_4")

# %%
f_all = list(set(f1 + f2 + f3 + f4))

# %%
f_all
# Out:
# ['409930622.csv',
#  '2644326817.csv',
#  '2617215392.csv',
#  '357658747.csv',
#  '2701892929.csv',
#  '5890401192.csv',
#  '4895924026.csv',
#  '3405011838.csv',
#  '2210059361.csv',
#  '3191027142.csv',
#  '4375016451.csv',
#  '3370085095.csv',
#  '2629294578.csv',
#  '363363320.csv',
#  '4463772847.csv',
#  '3009729697.csv',
#  '2360775984.csv',
#  '2412390588.csv',
#  '185075930.csv',
#  '4238762387.csv',
#  '4872587030.csv',
#  '2392760448.csv',
#  '2624979508.csv',
#  '3263141261.csv',
#  '4689003496.csv',
#  '3454149297.csv',
#  '5184996839.csv',
#  '2908960035.csv',
#  '2911552402.csv',
#  '4756089621.csv',
#  '2286236765.csv',
#  '4480560554.csv',
#  '2699983419.csv',
#  '4921350374.csv',
#  '2247138288.csv',
#  '4829255593.csv',
#  '3418373237.csv',
#  '2604462733.csv',
#  '3957074517.csv',
#  '4815043888.csv',
#  '486738076.csv',
#  '4708678343.csv',
#  '2467354185.csv',
#  '2290330500.csv',
#  '5079930983.csv',
#  '4571898363.csv',
#  '2337825352.csv',
# ...

# %%
f1_csv = ["./features_1/" + s  for s in f1]
f2_csv = ["./features_2/" + s for s in f2]
f3_csv = ["./features_3/" + s  for s in f3]
f4_csv = ["./features_4/" + s for s in f4]

# %%
f_all_csv = list(set(f1_csv + f2_csv + f3_csv + f4_csv))

# %%
f_all_csv
# Out:
# ['./features_3/2374289148.csv',
#  './features_3/2517637587.csv',
#  './features_3/2644906016.csv',
#  './features_4/4808255993.csv',
#  './features_4/451081733.csv',
#  './features_4/4770979319.csv',
#  './features_4/4643411517.csv',
#  './features_3/2252722473.csv',
#  './features_3/137430923.csv',
#  './features_4/3538487621.csv',
#  './features_4/4525917968.csv',
#  './features_3/146021298.csv',
#  './features_4/4448065365.csv',
#  './features_4/535179217.csv',
#  './features_4/4347441967.csv',
#  './features_3/3046916429.csv',
#  './features_4/4518349470.csv',
#  './features_4/4865409871.csv',
#  './features_3/23012579.csv',
#  './features_4/3418462699.csv',
#  './features_2/165764051.csv',
#  './features_4/4042673790.csv',
#  './features_4/429046716.csv',
#  './features_4/3602676311.csv',
#  './features_3/3234890865.csv',
#  './features_3/2103982884.csv',
#  './features_3/2086534745.csv',
#  './features_4/374176648.csv',
#  './features_2/1939130031.csv',
# ...

# %%
f_drive = os.listdir("./features_drive")

# %%
f_drive2 = os.listdir("./features_drive2")

# %%
f_restanti = os.listdir("./features_restanti")

# %%
#f_drive.remove("1368320477.csv")

# %%
f_all_drive = list(set(f_drive + f_drive2 + f_restanti))

# %%
f_drive_csv = ["./features_drive/" + s  for s in f_drive]
f_drive2_csv = ["./features_drive2/" + s for s in f_drive2]
f_restanti_csv = ["./features_restanti/" + s for s in f_restanti]

# %%
f_all_drive_csv = list(set(f_drive_csv + f_drive2_csv + f_restanti_csv))

# %%
df_train_hw[df_train_hw["file"].isin(f_all + f_all_drive)]
# Out:
#                 0                                1            file
# 0      1000092795  [{'height': 500, 'width': 333}]  1000092795.csv
# 1        10002456  [{'height': 374, 'width': 500}]    10002456.csv
# 2      1000268201  [{'height': 500, 'width': 375}]  1000268201.csv
# 3      1000344755  [{'height': 333, 'width': 500}]  1000344755.csv
# 4      1000366164  [{'height': 375, 'width': 500}]  1000366164.csv
# ...           ...                              ...             ...
# 28995   997338199  [{'height': 400, 'width': 500}]   997338199.csv
# 28996   997722733  [{'height': 500, 'width': 333}]   997722733.csv
# 28997   997876722  [{'height': 500, 'width': 333}]   997876722.csv
# 28998    99804383  [{'height': 500, 'width': 375}]    99804383.csv
# 28999   998845445  [{'height': 375, 'width': 500}]   998845445.csv
#
# [29000 rows x 3 columns]

# %%
df_train_hw[~df_train_hw["file"].isin(f_all + f_all_drive)]
# Out:
# Empty DataFrame
# Columns: [0, 1, file]
# Index: []

# %%
#[s.replace(".csv", ".jpg") for s in last_n[~last_n["file"].isin(full_f_drive)]["file"].values]

# %%
#f_drive = ["./features_drive/" + s for s in f_drive]

# %%
predictions = []

for filename in tqdm(f_all_csv + f_all_drive_csv):
    df = pd.read_csv(filename, index_col=0, header=0).T
    df["filename"] = filename
    df["id"] = str(filename).replace(".csv", "").replace("./features_restanti/", "").replace("./features_drive2/", "").replace("./features_drive/", "").replace("./features_1/", "").replace("./features_2/", "").replace("./features_3/", "").replace("./features_4/", "")
    predictions.append(df)

df_predictions = pd.concat(predictions, axis=0, ignore_index=True)
df_predictions
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 32021/32021 [18:29<00:00, 28.86it/s]
#                                                        0  \
# 0      {"features": "IjE4QWBlnkB0FLNAXI8GQfefwkAWWAtA...
# 1      {"features": "AAAAAHD+CkAAAAAAAAAAABQq2j8ASyNA...
# 2      {"features": "QtYBQBqPy0CM7DJArt75QObiC0EEfSBB...
# 3      {"features": "CXKCP8NarkAAAAAADuF3P6Z8Gj/uaKxA...
# 4      {"features": "J+yMQFCvuEAAAAAA6q5hPwAAAAAQ0CRA...
# ...                                                  ...
# 32016  {"features": "XQZIQGAthEEdGBhB8BN1QZ3yy0BrFx4/...
# 32017  {"features": "hS5bQTMlJkFY9e5AvBenQEQVoUDyuyVB...
# 32018  {"features": "MqjzPwAAAAAAAAAA3PUfQJvxND8SWZhA...
# 32019  {"features": "wgkPQQ7dDkCizA9BqVa5QRXHzkAFwr0/...
# 32020  {"features": "tpQsQZzuEEDdrw5BAAAAAKcYE0EAAAAA...
#
#                                                        1  \
# 0      [{"class": "Coat", "conf": 0.7781185507774353,...
# ...

# %%
df_predictions["id"] = df_predictions["id"].astype("int64")

# %%
df_train_hw = df_train_hw.rename(columns={0: 'id', 1: 'size'})
df_train_hw.head()
# Out:
#            id                             size            file
# 0  1000092795  [{'height': 500, 'width': 333}]  1000092795.csv
# 1    10002456  [{'height': 374, 'width': 500}]    10002456.csv
# 2  1000268201  [{'height': 500, 'width': 375}]  1000268201.csv
# 3  1000344755  [{'height': 333, 'width': 500}]  1000344755.csv
# 4  1000366164  [{'height': 375, 'width': 500}]  1000366164.csv

# %%
df_train_hw[df_train_hw["id"].isin(list(df_predictions["id"].values))]
# Out:
#                id                             size            file
# 0      1000092795  [{'height': 500, 'width': 333}]  1000092795.csv
# 1        10002456  [{'height': 374, 'width': 500}]    10002456.csv
# 2      1000268201  [{'height': 500, 'width': 375}]  1000268201.csv
# 3      1000344755  [{'height': 333, 'width': 500}]  1000344755.csv
# 4      1000366164  [{'height': 375, 'width': 500}]  1000366164.csv
# ...           ...                              ...             ...
# 28995   997338199  [{'height': 400, 'width': 500}]   997338199.csv
# 28996   997722733  [{'height': 500, 'width': 333}]   997722733.csv
# 28997   997876722  [{'height': 500, 'width': 333}]   997876722.csv
# 28998    99804383  [{'height': 500, 'width': 375}]    99804383.csv
# 28999   998845445  [{'height': 375, 'width': 500}]   998845445.csv
#
# [29000 rows x 3 columns]

# %%
final_df = pd.merge(df_train_hw, df_predictions, on="id").rename(columns={0: 'features', 1: 'labels'})
final_df
# Out:
#                id                             size            file  \
# 0      1000092795  [{'height': 500, 'width': 333}]  1000092795.csv
# 1        10002456  [{'height': 374, 'width': 500}]    10002456.csv
# 2      1000268201  [{'height': 500, 'width': 375}]  1000268201.csv
# 3      1000344755  [{'height': 333, 'width': 500}]  1000344755.csv
# 4      1000366164  [{'height': 375, 'width': 500}]  1000366164.csv
# ...           ...                              ...             ...
# 32016   997876722  [{'height': 500, 'width': 333}]   997876722.csv
# 32017    99804383  [{'height': 500, 'width': 375}]    99804383.csv
# 32018    99804383  [{'height': 500, 'width': 375}]    99804383.csv
# 32019   998845445  [{'height': 375, 'width': 500}]   998845445.csv
# 32020   998845445  [{'height': 375, 'width': 500}]   998845445.csv
#
#                                                 features  \
# 0      {"features": "ki89QAAAAAAAAAAAFvs8P3NUhz/ght1A...
# ...

# %%
final_df = final_df.drop_duplicates(subset = "id")
final_df
# Out:
#                id                             size            file  \
# 0      1000092795  [{'height': 500, 'width': 333}]  1000092795.csv
# 1        10002456  [{'height': 374, 'width': 500}]    10002456.csv
# 2      1000268201  [{'height': 500, 'width': 375}]  1000268201.csv
# 3      1000344755  [{'height': 333, 'width': 500}]  1000344755.csv
# 4      1000366164  [{'height': 375, 'width': 500}]  1000366164.csv
# ...           ...                              ...             ...
# 32011   997338199  [{'height': 400, 'width': 500}]   997338199.csv
# 32013   997722733  [{'height': 500, 'width': 333}]   997722733.csv
# 32015   997876722  [{'height': 500, 'width': 333}]   997876722.csv
# 32017    99804383  [{'height': 500, 'width': 375}]    99804383.csv
# 32019   998845445  [{'height': 375, 'width': 500}]   998845445.csv
#
#                                                 features  \
# 0      {"features": "ki89QAAAAAAAAAAAFvs8P3NUhz/ght1A...
# ...

# %%
json.loads(final_df["features"].iloc[1]).keys()
# Out:
# dict_keys(['features', 'num_boxes'])

# %%
json.loads(final_df["features"].iloc[1])["num_boxes"]
# Out:
# 6

# %%
import base64
import numpy as np

# %%
np.frombuffer(base64.b64decode(json.loads(final_df["features"].iloc[1])["features"]), np.float32).shape
# Out:
# (12324,)

# %%
12324/6
# Out:
# 2054.0

# %%
sg_tsv = './inference_test_all_1/features.tsv'
df_test = pd.read_csv(sg_tsv,sep='\t',header = None,converters={1:json.loads})#converters={1:ast.literal_eval})
df_test
# Out:
#                            0  \
# 0  COCO_val2014_000000000042
#
#                                                    1
# 0  {'features': 'rzjAPzICX0AAAAAAR5DJQPj6ykAAAAAA...

# %%
df_test[1].iloc[0]["num_boxes"]
# Out:
# 19

# %%
df_test[1].iloc[0]["features"]
# Out:
# '...'

# %%
np.frombuffer(base64.b64decode(df_test[1].iloc[0]["features"]), np.float32).shape
# Out:
# (39026,)

# %%
39026/19
# Out:
# 2054.0

# %%
#sg_tsv = './training/train.feature.tsv'
#df_val = pd.read_csv(sg_tsv,sep='\t',header = None,converters={1:json.loads})#converters={1:ast.literal_eval})
#df_val

# %%
np.frombuffer(base64.b64decode(df_val[1].iloc[4]["features"]), np.float32).shape
# Out:
# (20540,)

# %%
df_val[1].iloc[4]["num_boxes"]
# Out:
# 10

# %%
20540/10
# Out:
# 2054.0

# %%
#df_predictions[df_predictions["id"].isin(df_predictions[df_predictions["id"].duplicated()]["id"].values)].sort_values(by=['id']).head(100)

# %%
final_df[['id','labels']]
# Out:
#                id                                             labels
# 0      1000092795  [{"class": "Belt buckle", "conf": 0.5350186228...
# 1        10002456  [{"class": "Traffic light", "conf": 0.51291126...
# 2      1000268201  [{"class": "Dress", "conf": 0.9662193059921265...
# 3      1000344755  [{"class": "Rubber band", "conf": 0.7075430750...
# 4      1000366164  [{"class": "Drum (musical instrument)", "conf"...
# ...           ...                                                ...
# 32011   997338199  [{"class": "Curtain", "conf": 0.80887413024902...
# 32013   997722733  [{"class": "Sandal", "conf": 0.717478156089782...
# 32015   997876722  [{"class": "Apple", "conf": 0.9743674397468567...
# 32017    99804383  [{"class": "Signboard", "conf": 0.706024229526...
# 32019   998845445  [{"class": "Ladder", "conf": 0.995799362659454...
#
# [29000 rows x 2 columns]

# %%
final_df[['id','features']]
# Out:
#                id                                           features
# 0      1000092795  {"features": "ki89QAAAAAAAAAAAFvs8P3NUhz/ght1A...
# 1        10002456  {"features": "Ta8CQRDNxD81+ZRAPhfGQOb8wkCgvb5A...
# 2      1000268201  {"features": "fKqDQQAAAAA8P44/WHkaQfywkEAAAAAA...
# 3      1000344755  {"features": "u24FQFOHokAAAAAACkI9QBn70T8kwudA...
# 4      1000366164  {"features": "lJYiQV6dlT9WZDlAXJmOQL94t0AAshc8...
# ...           ...                                                ...
# 32011   997338199  {"features": "aPgEQQAAAAAAAAAAJX5TQAAAAADvJSY+...
# 32013   997722733  {"features": "9pzPP7/XVUEAAAAAnGWUPuE1T0H3ks1A...
# 32015   997876722  {"features": "mPJwQAAAAAAAAAAAuo71PzYZgkAaSe5A...
# 32017    99804383  {"features": "SwyYQBGga0A6YDY/AAAAAJCAgj8fi/s/...
# 32019   998845445  {"features": "QovFQE59yj8RE+A/AAAAANu9KEAxWotA...
#
# [29000 rows x 2 columns]

# %%
OUTPUT_DIR = 'Oscar/inference_test_segmentation_finale/'
LABEL_FILE = os.path.join(OUTPUT_DIR,'label.tsv')
FEATURE_FILE = os.path.join(OUTPUT_DIR,'features.tsv')
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    print(f"path to {OUTPUT_DIR} created")

tsv_writer(final_df[['id','labels']].values.tolist(),LABEL_FILE)
tsv_writer(final_df[['id','features']].values.tolist(),FEATURE_FILE)

yaml_dict = {"label": "label.tsv",
           "feature": "features.tsv",
           "img": "train.tsv",
           "hw": "train.hw.tsv"}

with open(op.join(OUTPUT_DIR, 'test.yaml'), 'w') as file:
    yaml.dump(yaml_dict, file)
# Out:
# path to Oscar/inference_test_segmentation_finale/ created

# %%
copyfile("./data/train.hw.tsv", os.path.join(OUTPUT_DIR,'train.hw.tsv'))
copyfile("./data/train.tsv", os.path.join(OUTPUT_DIR,'train.tsv'))
print("File .tsv creati")
# Out:
# File .tsv creati

# %% [markdown]
# # Generazione caption training

# %%
import json
 
f = open('dataset_flickr30k.json')

flicker_karpathy = json.load(f)

# %%
flicker_karpathy.keys()
# Out:
# dict_keys(['images', 'dataset'])

# %%
karpathy_split = {"train": [], "val": [], "restval": [], "test": []}
for elem in flicker_karpathy["images"]:
    karpathy_split[elem["split"]].append(elem)

# %%
len(karpathy_split["train"])
# Out:
# 29000

# %%
result = {
    "annotations" : [],
    "images": [],
    "type": "captions",
    "info": "dummy",
    "licenses": "dummy"
}

# %%
for img in tqdm(karpathy_split["train"]):
    image_id = str(img["filename"].replace(".jpg", ""))
    for caption in img["sentences"]:
        result["annotations"].append({"image_id": image_id, "id": caption["sentid"], "caption": caption["raw"]})
    result["images"].append({"id": image_id, "file_name": image_id})
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 29000/29000 [00:00<00:00, 192134.56it/s]

# %%
result["annotations"]
# Out:
# [{'image_id': '1000092795',
#   'id': 0,
#   'caption': 'Two young guys with shaggy hair look at their hands while hanging out in the yard.'},
#  {'image_id': '1000092795',
#   'id': 1,
#   'caption': 'Two young, White males are outside near many bushes.'},
#  {'image_id': '1000092795',
#   'id': 2,
#   'caption': 'Two men in green shirts are standing in a yard.'},
#  {'image_id': '1000092795',
#   'id': 3,
#   'caption': 'A man in a blue shirt standing in a garden.'},
#  {'image_id': '1000092795',
#   'id': 4,
#   'caption': 'Two friends enjoy time spent together.'},
#  {'image_id': '10002456',
#   'id': 5,
#   'caption': 'Several men in hard hats are operating a giant pulley system.'},
#  {'image_id': '10002456',
#   'id': 6,
#   'caption': 'Workers look down from up above on a piece of equipment.'},
#  {'image_id': '10002456',
#   'id': 7,
#   'caption': 'Two men working on a machine wearing hard hats.'},
#  {'image_id': '10002456',
#   'id': 8,
# ...

# %%
len(result["images"])
# Out:
# 29000

# %%
f = open('train_caption_coco_format.json', 'w')

json.dump(result, f)

# %%
f = open('train_caption.json', 'w')

json.dump(result["annotations"], f)

# %%
result_val = {
    "annotations" : [],
    "images": [],
    "type": "captions",
    "info": "dummy",
    "licenses": "dummy"
}

# %%
for img in tqdm(karpathy_split["val"]):
    image_id = str(img["filename"].replace(".jpg", ""))
    for caption in img["sentences"]:
        result_val["annotations"].append({"image_id": image_id, "id": caption["sentid"], "caption": caption["raw"]})
    result_val["images"].append({"id": image_id, "file_name": image_id})
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 1014/1014 [00:00<00:00, 67449.44it/s]

# %%
result_val.keys()
# Out:
# dict_keys(['annotations', 'images', 'type', 'info', 'licenses'])

# %%
result_val["annotations"]
# Out:
# [{'image_id': '1018148011',
#   'id': 335,
#   'caption': 'A group of people stand in the back of a truck filled with cotton.'},
#  {'image_id': '1018148011',
#   'id': 336,
#   'caption': 'Men are standing on and about a truck carrying a white substance.'},
#  {'image_id': '1018148011',
#   'id': 337,
#   'caption': 'A group of people are standing on a pile of wool in a truck.'},
#  {'image_id': '1018148011',
#   'id': 338,
#   'caption': 'A group of men are loading cotton onto a truck'},
#  {'image_id': '1018148011',
#   'id': 339,
#   'caption': 'Workers load sheared wool onto a truck.'},
#  {'image_id': '1029450589',
#   'id': 495,
#   'caption': 'An adult wearing a gray shirt with red sleeves sleeping on a couch.'},
#  {'image_id': '1029450589',
#   'id': 496,
#   'caption': 'A woman in black pants napping on the couch.'},
#  {'image_id': '1029450589',
#   'id': 497,
#   'caption': 'A man sleeping in a green room on a couch.'},
#  {'image_id': '1029450589',
#   'id': 498,
# ...

# %%
len(result_val["images"])
# Out:
# 1014

# %%
result_val["images"]
# Out:
# [{'id': '1018148011', 'file_name': '1018148011'},
#  {'id': '1029450589', 'file_name': '1029450589'},
#  {'id': '1029737941', 'file_name': '1029737941'},
#  {'id': '103205630', 'file_name': '103205630'},
#  {'id': '10350842', 'file_name': '10350842'},
#  {'id': '1054620089', 'file_name': '1054620089'},
#  {'id': '1056873310', 'file_name': '1056873310'},
#  {'id': '1072439304', 'file_name': '1072439304'},
#  {'id': '1073444492', 'file_name': '1073444492'},
#  {'id': '1092437557', 'file_name': '1092437557'},
#  {'id': '109671650', 'file_name': '109671650'},
#  {'id': '109738763', 'file_name': '109738763'},
#  {'id': '109982467', 'file_name': '109982467'},
#  {'id': '110269384', 'file_name': '110269384'},
#  {'id': '1107507919', 'file_name': '1107507919'},
#  {'id': '112243673', 'file_name': '112243673'},
#  {'id': '1124448967', 'file_name': '1124448967'},
#  {'id': '1126137905', 'file_name': '1126137905'},
#  {'id': '1128874064', 'file_name': '1128874064'},
# ...

# %%
f = open('val_caption_coco_format.json', 'w')

json.dump(result_val, f)

# %%
f = open('val_caption.json', 'w')

json.dump(result_val["annotations"], f)

# %%
result_val["annotations"][-10:]
# Out:
# [{'image_id': '981727078',
#   'id': 154855,
#   'caption': 'Two men are using phone-booths that are located shortly outside of the downtown area of a city, by some trees.'},
#  {'image_id': '981727078',
#   'id': 154856,
#   'caption': 'There is the last of the public telephone located in the state.'},
#  {'image_id': '981727078',
#   'id': 154857,
#   'caption': 'Two men are standing at telephone booths outside.'},
#  {'image_id': '981727078',
#   'id': 154858,
#   'caption': 'Two men on the phone at a bank of pay phones.'},
#  {'image_id': '981727078',
#   'id': 154859,
#   'caption': 'Two men using a pay phone.'},
#  {'image_id': '991459823',
#   'id': 154995,
#   'caption': "A woman in a printed red dress, and brown sandals, standing with another female who's wearing white summer pants, waiting to use a green port-a-potty along a stretch of concrete road."},
#  {'image_id': '991459823',
#   'id': 154996,
# ...

# %%
result_test = {
    "annotations" : [],
    "images": [],
    "type": "captions",
    "info": "dummy",
    "licenses": "dummy"
}

# %%
for img in tqdm(karpathy_split["test"]):
    image_id = str(img["filename"].replace(".jpg", ""))
    for caption in img["sentences"]:
        result_test["annotations"].append({"image_id": image_id, "id": caption["sentid"], "caption": caption["raw"]})
    result_test["images"].append({"id": image_id, "file_name": image_id})
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 90982.73it/s]

# %%
result_test.keys()
# Out:
# dict_keys(['annotations', 'images', 'type', 'info', 'licenses'])

# %%
result_test["annotations"][-10:]
# Out:
# [{'image_id': '97233789',
#   'id': 154710,
#   'caption': 'A man, who is wearing the tan coat, is gambling at a casino slot machine.'},
#  {'image_id': '97233789',
#   'id': 154711,
#   'caption': 'And older man is playing a slot machine at a casino type environment.'},
#  {'image_id': '97233789',
#   'id': 154712,
#   'caption': 'An older man is playing a video arcade game.'},
#  {'image_id': '97233789',
#   'id': 154713,
#   'caption': 'An old man playing a game at the casino.'},
#  {'image_id': '97233789',
#   'id': 154714,
#   'caption': 'Man playing slots in a casino.'},
#  {'image_id': '97234558',
#   'id': 154715,
#   'caption': 'A young girl wades out into the water wearing safety floatation devices on her arms.'},
#  {'image_id': '97234558',
#   'id': 154716,
#   'caption': 'The baby walks on the gold and sandy-colored beach with water splashing behind him.'},
#  {'image_id': '97234558',
#   'id': 154717,
# ...

# %%
len(result_test["images"])
# Out:
# 1000

# %%
result_test["images"]
# Out:
# [{'id': '1007129816', 'file_name': '1007129816'},
#  {'id': '1009434119', 'file_name': '1009434119'},
#  {'id': '101362133', 'file_name': '101362133'},
#  {'id': '102617084', 'file_name': '102617084'},
#  {'id': '10287332', 'file_name': '10287332'},
#  {'id': '1039637574', 'file_name': '1039637574'},
#  {'id': '1043819504', 'file_name': '1043819504'},
#  {'id': '1043910339', 'file_name': '1043910339'},
#  {'id': '1044798682', 'file_name': '1044798682'},
#  {'id': '1071201387', 'file_name': '1071201387'},
#  {'id': '107969134', 'file_name': '107969134'},
#  {'id': '1080230428', 'file_name': '1080230428'},
#  {'id': '1082250005', 'file_name': '1082250005'},
#  {'id': '1089059626', 'file_name': '1089059626'},
#  {'id': '109260218', 'file_name': '109260218'},
#  {'id': '109656696', 'file_name': '109656696'},
#  {'id': '1104087374', 'file_name': '1104087374'},
#  {'id': '110671448', 'file_name': '110671448'},
#  {'id': '111497985', 'file_name': '111497985'},
# ...

# %%
f = open('test_caption_coco_format.json', 'w')

json.dump(result_test, f)
a_file = open("test_caption_2.json", "w")
a_file = json.dump(result_test["annotations"], a_file)

f = open('test_caption.json', 'w')

json.dump(result_test["annotations"], f)

# %%
len('1000092795	[{"class": "Belt buckle", "conf": 0.5350186228752136, "rect": [217.0223846435547, 234.0861053466797, 223.67523193359375, 240.3889923095703]}, {"class": "Tree", "conf": 0.8952938318252563, "rect": [0, 0, 332, 421]}, {"class": "Sky", "conf": 0.9932218790054321, "rect": [175, 0, 300, 57]}, {"class": "Person", "conf": 0.9997443556785583, "rect": [162, 112, 257, 365]}, {"class": "Person", "conf": 0.996145486831665, "rect": [165, 123, 214, 333]}, {"class": "Grass", "conf": 0.9679450988769531, "rect": [0, 365, 332, 499]}, {"class": "Dirt", "conf": 0.9469869136810303, "rect": [139, 301, 332, 412]}]\n')
# Out:
# 609

# %%
len('10002456	[{"class": "Traffic light", "conf": 0.5129112601280212, "rect": [15.365641593933105, 162.34490966796875, 45.57206344604492, 214.3147430419922]}, {"class": "Sky", "conf": 0.9994383454322815, "rect": [0, 0, 499, 373]}, {"class": "Person", "conf": 0.9980964064598083, "rect": [188, 142, 253, 280]}, {"class": "Person", "conf": 0.9571835994720459, "rect": [386, 221, 417, 285]}, {"class": "Person", "conf": 0.9377817511558533, "rect": [254, 179, 326, 252]}, {"class": "Person", "conf": 0.934282124042511, "rect": [335, 155, 389, 237]}]\n')
# Out:
# 541

# %%
609 + 541
# Out:
# 1150

# %%
len('391895	[{"class":"Vehicle","conf":0.9939578771591187,"rect":[349.5537109375,122.79512786865234,480.8583679199219,353.5150451660156]},{"class":"Land vehicle","conf":0.9916129112243652,"rect":[349.91949462890625,120.98450469970703,482.0639343261719,354.3675537109375]},{"class":"Tree","conf":0.9869280457496643,"rect":[0.0,154.5780487060547,95.26521301269531,256.7273254394531]},{"class":"Person","conf":0.9807699918746948,"rect":[349.0257568359375,26.784536361694336,492.1134948730469,305.69061279296875]},{"class":"Footwear","conf":0.9799947738647461,"rect":[473.0546875,302.21337890625,495.2230529785156,323.9273986816406]},{"class":"Tree","conf":0.9766116142272949,"rect":[470.05828857421875,92.7939224243164,620.174560546875,211.82083129882812]},{"class":"Person","conf":0.940204918384552,"rect":[472.49700927734375,172.84579467773438,510.92901611328125,218.4593505859375]},{"class":"Helmet","conf":0.8481354713439941,"rect":[358.37542724609375,22.036651611328125,408.30322265625,64.53060150146484]},{"class":"Vehicle","conf":0.8056963682174683,"rect":[482.93536376953125,187.3244171142578,512.7965087890625,219.87342834472656]},{"class":"Land vehicle","conf":0.7983808517456055,"rect":[482.93463134765625,186.97596740722656,512.5547485351562,219.3457794189453]},{"class":"Motorcycle","conf":0.7608028650283813,"rect":[343.2215881347656,118.83432006835938,491.26934814453125,353.4541931152344]},{"class":"Wheel","conf":0.5888572335243225,"rect":[397.32012939453125,249.41197204589844,427.194580078125,355.07757568359375]},{"class":"Tree","conf":0.4755755662918091,"rect":[572.3621826171875,93.45824432373047,637.786376953125,202.09613037109375]},{"class":"Tire","conf":0.4463346004486084,"rect":[399.1748962402344,249.85888671875,426.5109558105469,356.88177490234375]},{"class":"Tree","conf":0.3805103003978729,"rect":[0.0,76.60124206542969,288.33843994140625,152.1858673095703]},{"class":"Tree","conf":0.3567180633544922,"rect":[0.0,32.05036163330078,630.5011596679688,218.7921600341797]},{"class":"Bicycle","conf":0.3323318362236023,"rect":[479.62799072265625,186.7733154296875,513.330078125,220.14866638183594]},{"class":"Tree","conf":0.2598313093185425,"rect":[5.032249450683594,46.598655700683594,404.58770751953125,187.12301635742188]},{"class":"Man","conf":0.25035592913627625,"rect":[343.2541809082031,32.063743591308594,493.5172119140625,312.2186584472656]},{"class":"Wheel","conf":0.228193998336792,"rect":[381.6778259277344,233.90077209472656,398.56805419921875,309.40362548828125]}]\n')
# Out:
# 2498

# %%
len('60623	[{"class":"Human face","conf":0.9978402853012085,"rect":[181.705810546875,62.89079284667969,293.4264831542969,241.85337829589844]},{"class":"Person","conf":0.9618567228317261,"rect":[6.369190692901611,0.0,390.3642883300781,422.599365234375]},{"class":"Person","conf":0.9475177526473999,"rect":[289.6355895996094,2.6672351360321045,583.7896118164062,322.5371398925781]},{"class":"Tableware","conf":0.9375392198562622,"rect":[378.2794189453125,103.96806335449219,528.263916015625,213.18862915039062]},{"class":"Drink","conf":0.9105503559112549,"rect":[560.60595703125,88.42829132080078,638.6270751953125,163.4915008544922]},{"class":"Tableware","conf":0.903062105178833,"rect":[409.55975341796875,237.8883056640625,546.9939575195312,351.3667297363281]},{"class":"Furniture","conf":0.7994781732559204,"rect":[311.00494384765625,80.74809265136719,639.4661865234375,426.46624755859375]},{"class":"Table","conf":0.797322690486908,"rect":[301.0498962402344,75.88475799560547,639.4661865234375,426.46624755859375]},{"class":"Spoon","conf":0.7473256587982178,"rect":[386.4492492675781,107.66059112548828,528.3748168945312,210.03712463378906]},{"class":"Candle","conf":0.6846438050270081,"rect":[428.9236755371094,233.82945251464844,467.3613586425781,283.98223876953125]},{"class":"Tableware","conf":0.5796670317649841,"rect":[555.0872802734375,29.380584716796875,639.4661865234375,205.435302734375]},{"class":"Human mouth","conf":0.5614772439002991,"rect":[258.99066162109375,164.77407836914062,287.6812438964844,229.4178924560547]},{"class":"Woman","conf":0.5431913733482361,"rect":[6.568428993225098,0.0,367.7642822265625,424.4947814941406]},{"class":"Bowl","conf":0.5179513096809387,"rect":[411.9393615722656,236.50343322753906,548.7373046875,348.3641357421875]},{"class":"Drink","conf":0.5132745504379272,"rect":[559.5820922851562,30.770984649658203,637.0328369140625,196.83314514160156]},{"class":"Wine glass","conf":0.48834386467933655,"rect":[557.2278442382812,27.905515670776367,639.4661865234375,209.89913940429688]},{"class":"Girl","conf":0.468942254781723,"rect":[7.3636393547058105,0.590711772441864,356.557861328125,426.46624755859375]},{"class":"Human nose","conf":0.4308543801307678,"rect":[254.9424591064453,107.7512435913086,288.48004150390625,153.0281219482422]},{"class":"Cocktail","conf":0.3871663212776184,"rect":[557.805908203125,19.84551239013672,638.841552734375,203.0253448486328]},{"class":"Human hand","conf":0.3859521746635437,"rect":[320.4210510253906,93.75968170166016,432.3847351074219,200.41485595703125]},{"class":"Human hand","conf":0.3143136501312256,"rect":[301.3798522949219,2.9165711402893066,421.6374206542969,66.36186218261719]},{"class":"Human head","conf":0.29705575108528137,"rect":[35.83633041381836,4.813848972320557,287.9605407714844,250.2738037109375]},{"class":"Dessert","conf":0.2780548632144928,"rect":[419.627685546875,244.55050659179688,534.1533813476562,327.9852294921875]},{"class":"Woman","conf":0.24206282198429108,"rect":[274.66259765625,0.0,606.0799560546875,370.7740783691406]},{"class":"Human arm","conf":0.22810332477092743,"rect":[291.0431823730469,10.270305633544922,585.2156372070312,208.71788024902344]}]\n')
# Out:
# 3167

# %%
2498 + 3167
# Out:
# 5665

# %%
len('1018148011	[{"class": "Truck", "conf": 0.7444072961807251, "rect": [0.0, 156.14093017578125, 112.75589752197266, 288.5873718261719]}, {"class": "Wheel", "conf": 0.6858968138694763, "rect": [83.48661041259766, 241.11776733398438, 114.40984344482422, 293.91302490234375]}, {"class": "Wheel", "conf": 0.6008502244949341, "rect": [30.432117462158203, 242.28515625, 67.71029663085938, 281.6181335449219]}, {"class": "Person", "conf": 0.9725155830383301, "rect": [282, 130, 299, 146]}, {"class": "Tree", "conf": 0.9512322545051575, "rect": [0, 0, 499, 199]}, {"class": "Person", "conf": 0.9328376650810242, "rect": [244, 119, 252, 137]}, {"class": "Person", "conf": 0.9558094143867493, "rect": [62, 206, 90, 289]}, {"class": "Person", "conf": 0.9731414914131165, "rect": [97, 41, 118, 94]}, {"class": "Person", "conf": 0.9923225045204163, "rect": [0, 216, 21, 290]}, {"class": "Person", "conf": 0.9957597851753235, "rect": [154, 47, 181, 96]}, {"class": "Person", "conf": 0.8980766534805298, "rect": [138, 67, 151, 90]}, {"class": "Person", "conf": 0.9948892593383789, "rect": [250, 116, 269, 154]}, {"class": "Person", "conf": 0.9934428930282593, "rect": [179, 59, 202, 100]}, {"class": "Dirt", "conf": 0.982693076133728, "rect": [0, 280, 396, 332]}, {"class": "Sky", "conf": 0.9995301961898804, "rect": [0, 0, 499, 186]}, {"class": "Fence", "conf": 0.983836829662323, "rect": [70, 139, 370, 236]}, {"class": "Person", "conf": 0.9995262622833252, "rect": [382, 198, 427, 332]}, {"class": "Rock", "conf": 0.8606728911399841, "rect": [356, 248, 386, 298]}]\n')
# Out:
# 1550

# %%
len('1029450589	[{"class": "Sofa", "conf": 0.9327452182769775, "rect": [0.0, 170.8138885498047, 387.34014892578125, 334.0]}, {"class": "Bottle cap", "conf": 0.8218855857849121, "rect": [392.5008850097656, 159.45335388183594, 402.38238525390625, 165.13369750976562]}, {"class": "Water bottle", "conf": 0.7727704048156738, "rect": [377.87945556640625, 161.305908203125, 413.3737487792969, 265.7025451660156]}, {"class": "Blanket", "conf": 0.5992669463157654, "rect": [0.0, 258.4532775878906, 258.5789489746094, 333.63299560546875]}, {"class": "Sofa", "conf": 0.5777310729026794, "rect": [103.95234680175781, 212.9623565673828, 358.4977722167969, 334.0]}, {"class": "Book", "conf": 0.9049283266067505, "rect": [446, 59, 474, 106]}, {"class": "Wall", "conf": 0.9961579442024231, "rect": [0, 0, 494, 230]}, {"class": "Table", "conf": 0.9661372303962708, "rect": [315, 220, 499, 333]}, {"class": "Paper", "conf": 0.9463356733322144, "rect": [194, 80, 352, 200]}, {"class": "Person", "conf": 0.9744179248809814, "rect": [0, 216, 300, 331]}, {"class": "Curtain", "conf": 0.9399946331977844, "rect": [441, 0, 499, 105]}, {"class": "Person", "conf": 0.9772815704345703, "rect": [162, 216, 301, 305]}, {"class": "Couch", "conf": 0.9961926937103271, "rect": [0, 168, 353, 333]}, {"class": "Bottle", "conf": 0.9982420206069946, "rect": [376, 159, 415, 269]}]\n')
# Out:
# 1341

# %%
len('1029737941	[{"class": "Earphone", "conf": 0.8826538324356079, "rect": [104.90516662597656, 90.23475646972656, 188.0257110595703, 191.94020080566406]}, {"class": "Umbrella", "conf": 0.8265573978424072, "rect": [347.8606262207031, 123.92333221435547, 374.5421142578125, 139.1912384033203]}, {"class": "Flower", "conf": 0.8233824968338013, "rect": [0.0, 188.79910278320312, 79.53059387207031, 276.62811279296875]}, {"class": "Skirt", "conf": 0.7479326725006104, "rect": [39.97257995605469, 391.947021484375, 217.7108917236328, 499.0029602050781]}, {"class": "Flower", "conf": 0.7426944971084595, "rect": [259.8415222167969, 206.45877075195312, 367.3434753417969, 291.5150451660156]}, {"class": "Glasses", "conf": 0.6379691362380981, "rect": [192.48092651367188, 280.66558837890625, 215.0777130126953, 286.2483825683594]}, {"class": "Bracelet", "conf": 0.6346613764762878, "rect": [330.3506164550781, 426.7382507324219, 343.394775390625, 439.37261962890625]}, {"class": "Flower", "conf": 0.5908117294311523, "rect": [161.48223876953125, 202.8101806640625, 215.5113983154297, 241.8173065185547]}, {"class": "Person", "conf": 0.9647966623306274, "rect": [175, 299, 333, 499]}, {"class": "Person", "conf": 0.9109463691711426, "rect": [262, 275, 299, 301]}, {"class": "Person", "conf": 0.8887999653816223, "rect": [239, 169, 270, 202]}, {"class": "Person", "conf": 0.9968679547309875, "rect": [24, 155, 75, 212]}, {"class": "Person", "conf": 0.8922232389450073, "rect": [276, 289, 326, 420]}, {"class": "Person", "conf": 0.9991739392280579, "rect": [30, 75, 270, 496]}, {"class": "Person", "conf": 0.972781240940094, "rect": [186, 265, 219, 315]}, {"class": "Person", "conf": 0.9104479551315308, "rect": [356, 269, 374, 325]}, {"class": "Potted plant", "conf": 0.943520188331604, "rect": [263, 210, 374, 285]}, {"class": "Person", "conf": 0.9477752447128296, "rect": [237, 291, 332, 499]}, {"class": "Person", "conf": 0.9889246821403503, "rect": [309, 246, 374, 499]}, {"class": "Tree", "conf": 0.9625073671340942, "rect": [0, 0, 374, 216]}, {"class": "Flower", "conf": 0.8972830772399902, "rect": [0, 190, 374, 282]}]\n')
# Out:
# 2111

# %%
1550 + 1341 + 2111
# Out:
# 5002

# %%
len('1000092795	[{"class": "Belt buckle", "conf": 0.5350186228752136, "rect": [217.0223846435547, 234.0861053466797, 223.67523193359375, 240.3889923095703]}, {"class": "Tree", "conf": 0.8952938318252563, "rect": [0, 0, 332, 421]}, {"class": "Sky", "conf": 0.9932218790054321, "rect": [175, 0, 300, 57]}, {"class": "Person", "conf": 0.9997443556785583, "rect": [162, 112, 257, 365]}, {"class": "Person", "conf": 0.996145486831665, "rect": [165, 123, 214, 333]}, {"class": "Grass", "conf": 0.9679450988769531, "rect": [0, 365, 332, 499]}, {"class": "Dirt", "conf": 0.9469869136810303, "rect": [139, 301, 332, 412]}]\n')
# Out:
# 609

# %%
609 + 541
# Out:
# 1150

# %%
len('10002456	[{"class": "Traffic light", "conf": 0.5129112601280212, "rect": [15.365641593933105, 162.34490966796875, 45.57206344604492, 214.3147430419922]}, {"class": "Sky", "conf": 0.9994383454322815, "rect": [0, 0, 499, 373]}, {"class": "Person", "conf": 0.9980964064598083, "rect": [188, 142, 253, 280]}, {"class": "Person", "conf": 0.9571835994720459, "rect": [386, 221, 417, 285]}, {"class": "Person", "conf": 0.9377817511558533, "rect": [254, 179, 326, 252]}, {"class": "Person", "conf": 0.934282124042511, "rect": [335, 155, 389, 237]}]\n')
# Out:
# 541
